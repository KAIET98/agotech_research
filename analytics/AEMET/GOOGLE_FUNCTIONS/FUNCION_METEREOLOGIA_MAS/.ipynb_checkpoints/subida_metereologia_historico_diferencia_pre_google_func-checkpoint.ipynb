# %% [markdown]
# <a href="https://colab.research.google.com/github/KAIET98/TFM_AGROTECH/blob/dinamiz_ubicacion/analytics/AEMET/SERVERLESS_DEPLOYMENT/Google%20Funcions/FUNCION_METEREOLOGIA_MAS/subida_metereologia_historico_diferencia_pre_google_func.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Fichero de subida de datos de metereologia historico a dinamico
# Su funcion es subir parte del historico que aún nos se ha subido a la base de datos, es decir lo justo de 2022-01-01 hasta el día 30-03-2022, antes de implementar la funcion de insertar datos en la tabla tal cual se ha hecho con la humedad.
#
# Definimos la funcion que nos ayudara a hacer la tarea:

# %%
#------------- EXTRACCION DATOS DESDE LA API DE AEMET -------------



'''
Este script tiene como objetvio automatizar la captación de todos los datos metereologicos
de una estación cualquiera de españa que se le proporcione
'''






#------------- EXTRACCION DATOS DESDE LA API DE AEMET -------------



'''
Este script tiene como objetvio automatizar la captación de todos los datos metereologicos
de una estación cualquiera de españa que se le proporcione
'''






#------------- EXTRACCION DATOS DESDE LA API DE AEMET -------------


'''
Establecemos la url de acceso a los datos junto a la key de KAIET
'''

'''
Vamos a crear una funcion para chequear si AEMET tiene historico de datos sobre la provincia que quiere 
checkear el usuario

'''






def mi_metereologia(codigo_estacion, desde, hasta, API_KEY, provincia):

    import pandas as pd
    import requests
    import json
    import numpy as np
    '''
    Esto nos devolvera  un booleano, es decir, si es que es true, lanzaremos las operaciones ordinarias tal y como hemos hecho hasta la fecha, 
    si no, le indicaremos con un mensaje que tenemos información sobre la estación que esta buscando.
    '''
    def info_mi_provincia(API_KEY):

        #'Extraemos cuales son las estaciuones que tiene miradas aemet.'

        url_estaciones = "https://opendata.aemet.es/opendata/api/valores/climatologicos/inventarioestaciones/todasestaciones/"
        querystring = {"api_key":API_KEY}

        headers = {
            'cache-control': "no-cache"
            }

        #Como lo hemos hecho en veces anteriores, nos quedamos ocn el apartado de 'DATOS' que no deja de ser una URL. 

        datos_url_plu = json.loads(requests.request("GET", url_estaciones, headers=headers, params=querystring).text)['datos']

        #Hacemos la request, y los resultados los guardamos en un dataframe. 

        todas_estaciones = pd.DataFrame(requests.get(datos_url_plu, params=querystring, verify=False).json())


        return todas_estaciones['provincia'].unique()


    if provincia in list(info_mi_provincia(API_KEY)):

        import urllib3
        urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)
        import pandas as pd
        import requests
        import json
        import numpy as np

        mi_provincia = provincia.upper()


        #1. Parametrizamos la estación, la API KEY como lafechas desde y hasta


        codigo_estacion_cercano = codigo_estacion
        
        #codigo_estacion_cercano = 8175

        #desde_Fecha = '2021-01-01'

        desde_Fecha = desde

        #hasta_fecha = '2021-02-10'
        
        hasta_fecha = hasta

        #API_KEY = 'eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJraWdsZXNpYXNiYXJhaWJhckBzdHVkZW50LmVhZS5lcyIsImp0aSI6ImY4YWQ5OGRmLTkzMjQtNDEzMi05NjY3LTdjY2E2Nzc3Mzc0NiIsImlzcyI6IkFFTUVUIiwiaWF0IjoxNjQyOTYzODc0LCJ1c2VySWQiOiJmOGFkOThkZi05MzI0LTQxMzItOTY2Ny03Y2NhNjc3NzM3NDYiLCJyb2xlIjoiIn0.en7xw4HHYaZ4oW8qooX6wGG3yn1Tv3OzFfnhrZac6vo'
        API_KEY =  API_KEY 


        url = ("https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos"
            "/fechaini/{}T00:00:00UTC/fechafin/{}T00:00:00UTC/estacion/{}".format(desde_Fecha,\
                hasta_fecha,\
                    codigo_estacion_cercano))

        
        querystring = {"api_key": API_KEY}
            
        r = requests.get(url, params=querystring, verify=False)

        #Creamos una función que transformarra los datos numericos reemplazando la coma por el punto

        def parse_data(raw_data):
            data = []
            for d in raw_data:
                d = dict(d)  # Exto copia el parámetro
                for param in ['prec', 'presMax', 'presMin', 'racha', 'sol', 'tmax', 'tmed', 'tmin', 'velmedia', 'altitud', 'dir']:
                    try:
                        d[param] = float(d[param].replace(',', '.'))
                    except:
                        d[param] = None

                data.append(d)
            return data


        #Finalmente lanamos la query y si es que todo  va bien extraemos la información

        try: 

            if r.status_code == requests.codes.OK:
                #print(r.json())

                data_url = r.json()['datos']
            

                #print('\n La url que vamos a gestionar es: ', data_url, '\n')

                r_data = requests.get(data_url, params=querystring, verify=False)

                #print('Y los datos son: ', r_data)

                #Una vez que sabemos que podemos extraer los dtos, los transformamos a un formato json.

                raw_data = r_data.json()
        
                #aplicamos la funcion recientemente creada par la transformacion decimal

                raw_data = parse_data(raw_data)

                #guardamos con los datos en el dataframe

                información_base_cercana = pd.DataFrame(raw_data)


                
                
                print('Se ha extraido la información de AEMET')

        except: 

            print('La extracción de información falla, checkea las credenciales')



        #---------------- EXTRAEMOS LA INFORMACIÓN DE LAS DEMÁS ESTACIONES DE LA PROVINCIA
        # 
        def busqueda_metricas_temperatura_media(nombre_estacion, diccionario):
        
        #0. Extraemos la información de una estación filtrando por el nombre de la estacion
        #le añadimos el drop index, porque luego, más adelante reseeteamos el index para que el código funcione
        #bien. Por loq ue, al genera un indice natural de python, el indice antiguo nos pasa como nueva columna y eso
        #no nos intereesa. 

            estacion_actual = estaciones_provincia[estaciones_provincia['Estacion'] == nombre_estacion].drop('index', axis = 1)

            #1. Nos qudamos con el código identificativo de la estacion de interes
            
            codigo_estacion_actual = estacion_actual.iloc[0,0]

            print('El codigo es: ', codigo_estacion_actual)
        # print(codigo_estacion_actual)

            #2. Utilizamos el codigo de la estación para extraer la infomración metereológica


            '''
            
            El que funcionaba hasta ahora: 

            url = ("https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos"
                "/fechaini/{}T00:00:00UTC/fechafin/{}T00:00:00UTC/estacion/{}".format('2021-01-01', '2022-02-10',\
                                                                                        codigo_estacion_actual))

            '''

            url = ("https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos"
                "/fechaini/{}T00:00:00UTC/fechafin/{}T00:00:00UTC/estacion/{}".format(desde_Fecha, hasta_fecha,\
                                                                                        codigo_estacion_actual))

            API_KEY = 'eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJraWdsZXNpYXNiYXJhaWJhckBzdHVkZW50LmVhZS5lcyIsImp0aSI6ImY4YWQ5OGRmLTkzMjQtNDEzMi05NjY3LTdjY2E2Nzc3Mzc0NiIsImlzcyI6IkFFTUVUIiwiaWF0IjoxNjQyOTYzODc0LCJ1c2VySWQiOiJmOGFkOThkZi05MzI0LTQxMzItOTY2Ny03Y2NhNjc3NzM3NDYiLCJyb2xlIjoiIn0.en7xw4HHYaZ4oW8qooX6wGG3yn1Tv3OzFfnhrZac6vo'

            querystring = {"api_key": API_KEY}
                
            r = requests.get(url, params=querystring, verify=False)

            
            #Vemos si se hace la llamada correctamente

            if r.status_code == 200:
                
                #3. Nos qudamos con el apartado de 'datos' una vez transformada a json, que es una URL
                #print(r.json())

                print(r.json())

                #una vez que se hace la llamada, vamos a ver cúal es su contenido, 
                #si realmetne nos devuelve contenido por ejemplo.

                if r.json()['estado'] == 200:

                    data_url = r.json()['datos']

                    #4. Hacemos la petición a la API.

                    r_data = requests.get(data_url, params=querystring, verify=False)

                    #5. Hacemos la transfomración a JSON.

                    raw_data = r_data.json()

                    #6. Cambiamos los decimales de coma a punto

                    raw_data = parse_data(raw_data)
                    

                    #7. Guardamos el output en un dataframe

                    información_base_cercana_temp = pd.DataFrame(raw_data)

                    print("\n", " los datos que obtenemos son: ")

                    print(información_base_cercana_temp.head())

                    #8.Y nos quedamos con la ifnormación de la fecha y con la temperatura media de dicha estacion

                    información_temp_media = información_base_cercana_temp.loc[:,['fecha','tmed']]

                    

                    #print('Los datos de esta estacion son: ', información_temp_media['tmed'].values.tolist()[:5])

                    #Finalmente, esta ifnormación la transladamos a lita para poder guardarlo junto al código de la estación de interés

                    diccionario[nombre_estacion] = información_temp_media['tmed'].values.tolist()

                else: 

                    print('No hay información sobre esta estacion')
            #información_temp_media =

             

        '''
        Dicho esto, creamos un diccionario para guardar la información de la formula que acabamos e crear, 
        y le pasamos la información de las estaciones de la provinica de interés. Pero para ello necesitamos saber cuales son 
        las estaciones de albacete

        '''

        url_estaciones = "https://opendata.aemet.es/opendata/api/valores/climatologicos/inventarioestaciones/todasestaciones/"
        querystring = {"api_key":API_KEY}

        headers = {
            'cache-control': "no-cache"
            }

        #Como lo hemos hecho en veces anteriores, nos quedamos ocn el apartado de 'DATOS' que no deja de ser una URL. 

        datos_url_plu = json.loads(requests.request("GET", url_estaciones, headers=headers, params=querystring).text)['datos']

        #Hacemos la request, y los resultados los guardamos en un dataframe. 

        todas_estaciones = pd.DataFrame(requests.get(datos_url_plu, params=querystring, verify=False).json())


        #print(todas_estaciones)

        #print(todas_estaciones[todas_estaciones['provincia'] == mi_provincia])


        #Una vez que hemos logrado las estaciones filtramos por la provincia que nos interesa.

        estaciones_provincia = todas_estaciones[todas_estaciones['provincia'] == mi_provincia][['indicativo', 'latitud', 'nombre', 'longitud']]


        #estaciones_albacete = todas_estaciones[todas_estaciones['provincia'] == 'ALBACETE'][['indicativo', 'latitud', 'nombre', 'longitud']]

        #Una vez que tenemos las estaciones de la provincia accionamos la formula creada para obtener las temepraturas medias.


        #restablecemos el índice para que cuente desde el 0 sino no va a funcionar el script

        estaciones_provincia = estaciones_provincia.rename(columns={'nombre': 'Estacion'}).reset_index()
        #print(estaciones_albacete)

        #print(estaciones_albacete)

        #print(estaciones_albacete.loc[0,'Estacion'])



        estaciones = {}

        for estac in range(0,estaciones_provincia.shape[0]):

            #por cada estacion en la tabla de estaciones de esa provincia
            #nos quedamos con el codigo de esa provincia: 

            nombre_estacion = estaciones_provincia.loc[estac,'Estacion']
            #print(nombre_estacion)
            busqueda_metricas_temperatura_media(nombre_estacion, estaciones)


        #Transfomramos el output en un dataframe operativo

        temperatura_media_estaciones = pd.DataFrame.from_dict(estaciones, orient='index').T

        #si hay NAs los reemplazamos por 0


        temperatura_media_estaciones = temperatura_media_estaciones.fillna(0)

        #Creamos la columna de la media de las estaciones diarias

        temperatura_media_estaciones['mean_tmed'] = temperatura_media_estaciones.mean(axis=1)


        #Adjuntamos la fecha a la que se referencia cada media diaria

        temperatura_media_estaciones['fecha'] = información_base_cercana['fecha']


        #y nos quedamos solamente con los dos datos, la media diaria y la fecha

        temperatura_media_estaciones = temperatura_media_estaciones[['fecha', 'mean_tmed']]

        #---------------- JUNTAMOS LA INFORMACIÓN DE LAS DEMAS ESTACIONES OCN LA DE LA BASE AEREA

        información_base_cercana['prov_tmed'] = temperatura_media_estaciones['mean_tmed']

        #√emos el resultado del matching

        #print(información_base_cercana.head())

        #---------------- CREAMOS LAS NUEVAS METRICAS DE DATOS 

        '''
        Si la temperatura exterior cae bajo los 7 grados, se sabe que el almendro puede empezar a caer en periodo de hibernación
        Por lo que vamos a tener que investigar si este caso ocurre . 
        '''

        import numpy as np

        #primero nos interesa si ha estado dorido o no ha estado dormido

        información_base_cercana['almendro_sueño'] = información_base_cercana['tmed'] < 7

        #luego nos interesa saber a cuantos grados ha etado dormido si es true

        información_base_cercana['dor_grados'] = 7 - información_base_cercana['tmed']

        #solo queremos reperesentar los valores que ha estado realmente por debajo de 7 grados, por lo que
        #todas aquellas veces que ha estado por encima, lo reemplazamos por 0. 

        información_base_cercana['dor_grados'] = np.where(información_base_cercana['dor_grados'] > 0,\
        información_base_cercana['dor_grados'], 0)


        '''
        En cuanto a la presión se refiere, también nos es de mucha interes porque es un medio que usan las 
        plantas para absorver la humedad de la tierra. 
        La presión interna tiene que ser superior a la externa. Nosotros de esta fuente solo tenemos la presión 
        externa, por lo que vamos a llamalo como tal. 

        '''

        información_base_cercana['Presion_externa'] = (información_base_cercana['presMax'] + información_base_cercana['presMin'])/2

        #--------------- CAMBIAMOS LOS NOMBRES DE LAS COLUMNAS 


        información_base_cercana = información_base_cercana[['fecha', 'nombre', 	'provincia','tmed','prec','tmin','tmax','dir','velmedia','presMax','presMin','prov_tmed','dor_grados', 'Presion_externa']]

        #cambiamos los nombres de las columnas a otros más comprensibles

        información_base_cercana = información_base_cercana.rename(columns={'nombre': 'Estacion', 'provincia': 'Provincia', 'tmed': 'Temperatura_media', 'prec':'Precipitacion_l_m3', 'tmin':'Temperatura_minima','tmax':'Temperatura_maxima','dir':'Direccion_viento','velmedia':'Velocidad_media','velmedia':'Velocidad_media','presMax':'Presion_maxima', 'presMin':'Presion_minima', 'prov_tmed':'Prom_temperatura_media_prov', 'dor_grados':'Grados_debajo_siete'})


        return información_base_cercana

    

    else:

        print('AEMET no tiene información acerca de la estación que estás intentando buscar')

# %% [markdown]
# Importamos el código y paquetes necesarios para poder subir los datos historicos del 2022

# %%
# !pip install pymysql
# Out:
# Looking in indexes: https://aws:****@ocsddna-112555760202.d.codeartifact.eu-west-1.amazonaws.com/pypi/ddna-mgmt/simple/
# Requirement already satisfied: pymysql in c:\users\kaiet.iglesias_bluet\desktop\virtual_envs\tfm\lib\site-packages (1.0.2)
# WARNING: You are using pip version 21.2.4; however, version 22.1 is available.
# You should consider upgrading via the 'C:\Users\kaiet.iglesias_bluet\Desktop\VIRTUAL_ENVS\TFM\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
#El objetivo de esta función es la construcción de una función que sirva para insertar 
#lineas en una tabla de sql.

import pandas as pd
import numpy as np
import pymysql
#import cryptography
import pandas as pd

'''
------------------- AWS OLD CONNECTION --------------
host = 'database-1.cq2dp4jmizro.eu-west-1.rds.amazonaws.com'
user = 'admin'
password = '12345678'
database = 'GET_DATABASE'

'''
#----------------------- GCP connection-----------------

host = '34.79.75.171'
user = 'admin'
password = '12345678'
database = 'GET_DATABASE'

def insert_into(data, arrival_df):

    #establecemos la conexión a la base de datos
    connection = pymysql.connect(host=host,
                             user=user,
                             password=password,
                             db=database)

    cursor = connection.cursor()


    #especificamos cual es el nombre de la tabla destino

    nombre_tabla = arrival_df

    
    # creating column list for insertion
    cols = "`,`".join([str(i) for i in data.columns.tolist()])
    cols = cols.strip()
    # Insert DataFrame recrds one by one.
    for i,row in data.iterrows():
        sql = "INSERT INTO `{}` (`".format(nombre_tabla) +cols + "`) VALUES (" + "%s,"*(len(row)-1) + "%s)"

            
        cursor.execute(sql, tuple(row))

            # the connection is not autocommitted by default, so we must commit to save our changes
        connection.commit()

# %% [markdown]
# Hacemos la subida de datos historicos hasta la fecha 25/03/2022

# %%
import logging
import requests
import pymysql

host = '34.79.75.171'
user = 'admin'
password = '12345678'
database = 'GET_DATABASE'




'''
def conectame(host, user, password, database):

    #conn = pymysql.connect(host=host, user=user, password=password, port=3306, db='GET_DATABASE',charset='utf8')

    connection = pymysql.connect(host=host,
                                user=user,
                                password=password,
                                db=database)

    cursor = connection.cursor()

    return cursor
cursor = conectame(host, user, password, database)
'''

logger = logging.getLogger()
logger.setLevel(logging.INFO)

try:
    conn = pymysql.connect(host=host, user=user, passwd=password, db=database, connect_timeout=5)
except pymysql.MySQLError as e:
    logger.error("ERROR: Unexpected error: Could not connect to MySQL instance.")
    logger.error(e)
    #sys.exit()

logger.info("SUCCESS: Connection to RDS MySQL instance succeeded")

#------------------ creamos la tabla ---------------

def run_query(q):
  with pymysql.connect(host=host,
                             user=user,
                             password=password,
                             db=database) as conn:
                             return pd.read_sql(q, conn)




#provincia = 'ALBACETE'
provincia = 'MADRID'

df = mi_metereologia(8175, '2022-01-01', '2022-03-25',\
                     'eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJraWdsZXNpYXNiYXJhaWJhckBzdHVkZW50LmVhZS5lcyIsImp0aSI6ImY4YWQ5OGRmLTkzMjQtNDEzMi05NjY3LTdjY2E2Nzc3Mzc0NiIsImlzcyI6IkFFTUVUIiwiaWF0IjoxNjQyOTYzODc0LCJ1c2VySWQiOiJmOGFkOThkZi05MzI0LTQxMzItOTY2Ny03Y2NhNjc3NzM3NDYiLCJyb2xlIjoiIn0.en7xw4HHYaZ4oW8qooX6wGG3yn1Tv3OzFfnhrZac6vo', 
                     provincia = provincia)
    
    #Se reemplazan los nas por 999

df = df.fillna(999)

    #print(df.head())


  #-------- SUBIMOS LOS DATOS --------#

print(df.head() , "\n")

print(df.tail())

print('Insertamos los datos...')



#insert_into(df, 'METEREOLOGIA')
# Out:
# ERROR: Unexpected error: Could not connect to MySQL instance.
# (2003, "Can't connect to MySQL server on '34.79.75.171' (timed out)")
# C:\Users\kaiet.iglesias_bluet\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'opendata.aemet.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# Se ha extraido la información de AEMET
# El codigo es:  2462
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/540647c5', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
#
#   los datos que obtenemos son:
#         fecha indicativo                 nombre provincia  altitud  tmed  \
# 0  2022-01-01       2462  PUERTO DE NAVACERRADA    MADRID   1894.0  10.6
# 1  2022-01-02       2462  PUERTO DE NAVACERRADA    MADRID   1894.0   9.8
# 2  2022-01-03       2462  PUERTO DE NAVACERRADA    MADRID   1894.0   7.8
# 3  2022-01-04       2462  PUERTO DE NAVACERRADA    MADRID   1894.0   1.6
# 4  2022-01-05       2462  PUERTO DE NAVACERRADA    MADRID   1894.0  -3.0
#
#    prec  tmin horatmin  tmax horatmax   dir  velmedia  racha horaracha  sol  \
# 0   0.0   7.4    00:10  13.7   Varias  22.0       3.9   12.2     22:30  8.1
# 1   0.0   6.0    20:40  13.5    13:30  22.0       2.5   11.1     00:00  6.0
# 2   0.0   4.2    06:20  11.3   Varias  27.0       3.1   15.3     22:50  7.6
# 3  24.2  -3.9    23:59   7.0    01:40  33.0       7.8   23.6     18:30  3.3
# 4  13.9  -4.2    03:10  -1.8   Varias  32.0       4.2   19.2     00:30  0.0
#
#    presMax horaPresMax  presMin horaPresMin
# 0    823.3          11    821.8          06
# 1    823.5      Varias    821.5      Varias
# 2    821.5          00    814.7          24
# 3    814.7          00    803.6          17
# 4    809.5          11    806.4      Varias
# El codigo es:  3100B
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/1d83291d', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
#
#   los datos que obtenemos son:
#         fecha indicativo    nombre provincia  altitud  tmed  prec  tmin  \
# 0  2022-01-01      3100B  ARANJUEZ    MADRID    540.0   8.4   0.0  -1.0
# 1  2022-01-02      3100B  ARANJUEZ    MADRID    540.0   8.3   0.0  -0.1
# 2  2022-01-03      3100B  ARANJUEZ    MADRID    540.0   8.6   0.0   0.7
# 3  2022-01-04      3100B  ARANJUEZ    MADRID    540.0   9.2   2.5   2.2
# 4  2022-01-05      3100B  ARANJUEZ    MADRID    540.0   6.8   2.8   2.6
#
#   horatmin  tmax horatmax   dir  velmedia  racha horaracha presMax presMin  \
# 0    07:00  17.7    14:50   9.0       0.6    4.7     10:40    None    None
# 1   Varias  16.7    15:00  11.0       1.1    4.7     10:50    None    None
# 2    07:00  16.6    15:40   9.0       0.3    4.7     09:30    None    None
# 3    07:50  16.3    14:40  25.0       2.8   15.3     15:50    None    None
# 4    05:30  10.9    13:00  29.0       3.3   10.0     12:00    None    None
#
#     sol
# 0  None
# 1  None
# 2  None
# 3  None
# 4  None
# El codigo es:  3110C
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/5c992e8d', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
#
#   los datos que obtenemos son:
#         fecha indicativo               nombre provincia  altitud  tmed  prec  \
# 0  2022-01-01      3110C  BUITRAGO DEL LOZOYA    MADRID   1030.0   8.4   0.0
# 1  2022-01-02      3110C  BUITRAGO DEL LOZOYA    MADRID   1030.0   8.4   0.0
# 2  2022-01-03      3110C  BUITRAGO DEL LOZOYA    MADRID   1030.0   7.8   0.0
# 3  2022-01-04      3110C  BUITRAGO DEL LOZOYA    MADRID   1030.0   7.3   9.1
# 4  2022-01-05      3110C  BUITRAGO DEL LOZOYA    MADRID   1030.0   3.5   2.9
#
#    tmin horatmin  tmax horatmax   dir  velmedia  racha horaracha  presMax  \
# 0  -0.7    06:30  17.6    14:10  99.0       0.6    3.1    Varias    914.7
# 1   0.2    04:30  16.7    13:50   9.0       0.8    3.9     14:10    915.0
# 2   1.0   Varias  14.5    14:00  11.0       0.6    4.7     14:20    913.3
# 3   3.0    23:59  11.6    13:10  27.0       1.1   11.7     23:10    905.6
# 4   0.7    20:10   6.3    12:50  25.0       1.9   11.4     03:50    903.6
#
#   horaPresMax  presMin horaPresMin   sol
# 0          10    912.5          15  None
# 1          10    912.5          15  None
# 2          00    905.6          24  None
# 3          00    895.1          15  None
# 4          11    899.7          21  None
# El codigo es:  3191E
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/3fe64a0f', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
#
#   los datos que obtenemos son:
#         fecha indicativo          nombre provincia  altitud  tmed  prec  tmin  \
# 0  2022-01-01      3191E  COLMENAR VIEJO    MADRID   1004.0  13.8   0.0   9.5
# 1  2022-01-02      3191E  COLMENAR VIEJO    MADRID   1004.0  11.8   0.0   8.3
# 2  2022-01-03      3191E  COLMENAR VIEJO    MADRID   1004.0   9.6   0.0   6.5
# 3  2022-01-04      3191E  COLMENAR VIEJO    MADRID   1004.0   7.4   4.8   4.2
# 4  2022-01-05      3191E  COLMENAR VIEJO    MADRID   1004.0   3.1   3.5  -0.5
#
#   horatmin  tmax horatmax   dir  velmedia  racha horaracha  sol  presMax  \
# 0    03:50  18.0    15:10  32.0       0.8    3.1     00:50  8.1    914.5
# 1    23:59  15.3    14:45  35.0       0.3    4.7     20:00  5.5    915.3
# 2    08:00  12.7   Varias  17.0       1.1    4.7     15:10  6.7    913.6
# 3    23:59  10.5    11:20  36.0       3.3   22.2     18:00  2.7    906.6
# 4    23:59   6.7    12:30  32.0       1.1   21.1     00:10  5.0    903.4
#
#   horaPresMax  presMin horaPresMin
# 0          10    913.3          15
# 1          10    913.5          05
# 2          00    906.6          24
# 3          00    894.0          16
# 4          12    900.0          21
# El codigo es:  3200
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/8423a301', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
#
#   los datos que obtenemos son:
#         fecha indicativo  nombre provincia  altitud  tmed  prec  tmin  \
# 0  2022-01-01       3200  GETAFE    MADRID    620.0  10.8   0.0   2.8
# 1  2022-01-02       3200  GETAFE    MADRID    620.0   9.5   0.0   3.0
# 2  2022-01-03       3200  GETAFE    MADRID    620.0   9.1   0.0   3.2
# 3  2022-01-04       3200  GETAFE    MADRID    620.0   9.1   6.4   3.8
# 4  2022-01-05       3200  GETAFE    MADRID    620.0   7.6   4.3   4.7
#
#   horatmin  tmax horatmax   dir  velmedia  racha horaracha  sol  presMax  \
# 0    07:10  18.8    15:50  16.0       0.8    3.6     12:31  8.3    958.1
# 1    07:30  16.0    15:15  26.0       0.8    3.1     10:40  7.8    958.8
# 2    07:30  15.0    15:00  29.0       0.8    4.7     15:14  7.9    956.8
# 3    05:30  14.4    14:00  31.0       2.5   16.9     15:50  1.8    949.4
# 4    21:00  10.6    12:50  33.0       5.0   16.4     00:03  5.6    947.7
#
#   horaPresMax  presMin horaPresMin
# 0          10    955.6          17
# 1          10    956.0          16
# 2      Varias    949.4          24
# 3      Varias    938.2          15
# 4          11    943.4          21
# El codigo es:  3129
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/132dc1fa', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
#
#   los datos que obtenemos son:
#         fecha indicativo             nombre provincia  altitud  tmed  prec  \
# 0  2022-01-01       3129  MADRID AEROPUERTO    MADRID    609.0   8.4   0.0
# 1  2022-01-02       3129  MADRID AEROPUERTO    MADRID    609.0   7.2   0.0
# 2  2022-01-03       3129  MADRID AEROPUERTO    MADRID    609.0   7.8   0.0
# 3  2022-01-04       3129  MADRID AEROPUERTO    MADRID    609.0   6.6   5.8
# 4  2022-01-05       3129  MADRID AEROPUERTO    MADRID    609.0   6.8   5.7
#
#    tmin horatmin  tmax horatmax   dir  velmedia  racha horaracha  sol  \
# 0  -0.3    08:10  17.2    15:01  35.0       0.8    4.2     20:40  8.0
# 1  -0.1    06:52  14.5    14:28  99.0       0.8    4.2    Varias  5.8
# 2   1.1    06:18  14.5    15:08  21.0       1.4    5.0     19:17  7.0
# 3   0.4    05:37  12.8    14:41  24.0       4.2   18.1     15:56  0.1
# 4   3.5    23:58  10.1    13:27  28.0       2.5   11.4     02:41  3.1
#
#    presMax horaPresMax  presMin horaPresMin
# 0    962.2      Varias    959.4          14
# 1    963.1      Varias    959.9          16
# 2    961.0          00    953.6          24
# 3    953.6          00    941.7          15
# 4    951.8      Varias    947.7          21
# El codigo es:  3194U
# {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
# No hay información sobre esta estacion
# El codigo es:  3196
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/647de558', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
#
#   los datos que obtenemos son:
#         fecha indicativo                  nombre provincia  altitud  tmed  \
# 0  2022-01-01       3196  MADRID, CUATRO VIENTOS    MADRID    690.0  11.4
# 1  2022-01-02       3196  MADRID, CUATRO VIENTOS    MADRID    690.0  10.2
# 2  2022-01-03       3196  MADRID, CUATRO VIENTOS    MADRID    690.0  10.0
# 3  2022-01-04       3196  MADRID, CUATRO VIENTOS    MADRID    690.0   7.8
# 4  2022-01-05       3196  MADRID, CUATRO VIENTOS    MADRID    690.0   6.5
#
#    prec  tmin horatmin  tmax horatmax   dir  velmedia  racha horaracha  sol  \
# 0   0.0   3.7    07:15  19.0    14:45  35.0       0.8    4.7     03:50  8.4
# 1   0.0   4.0   Varias  16.5    15:00  12.0       0.3    4.2     16:00  7.0
# 2   0.0   4.3   Varias  15.8    13:50  22.0       1.1    5.3     14:40  7.8
# 3   6.1   3.6    05:20  12.0    13:45  26.0       2.5   19.2     15:50  1.0
# 4   6.1   3.5    23:59   9.5    13:10  29.0       3.6   12.8     00:10  5.0
#
#    presMax horaPresMax  presMin horaPresMin
# 0    949.9          10    947.7          15
# 1    950.6          10    948.0          16
# 2    948.7          00    941.3          24
# 3    941.3          00    930.5          15
# 4    939.5          11    935.4          21
# El codigo es:  3195
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/89e61fc3', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
#
#   los datos que obtenemos son:
#         fecha indicativo          nombre provincia  altitud  tmed  prec  tmin  \
# 0  2022-01-01       3195  MADRID, RETIRO    MADRID    667.0  11.1   0.0   5.5
# 1  2022-01-02       3195  MADRID, RETIRO    MADRID    667.0   9.8   0.0   5.1
# 2  2022-01-03       3195  MADRID, RETIRO    MADRID    667.0   9.7   0.0   5.6
# 3  2022-01-04       3195  MADRID, RETIRO    MADRID    667.0   8.6   7.3   5.2
# 4  2022-01-05       3195  MADRID, RETIRO    MADRID    667.0   6.6   5.0   4.3
#
#   horatmin  tmax horatmax  presMax horaPresMax  presMin horaPresMin racha  \
# 0    07:10  16.7    14:50    951.5          11    949.3          14  None
# 1    07:40  14.5    15:00    952.2          10    949.5          16  None
# 2    07:30  13.8    15:50    950.2          00    942.8          24  None
# 3    05:30  12.1    14:00    942.9          00    931.7          15  None
# 4    04:20   8.9    14:00    941.0          11    936.9          21  None
#
#     sol velmedia   dir
# 0  None     None  None
# 1  None     None  None
# 2  None     None  None
# 3  None     None  None
# 4  None     None  None
# El codigo es:  3266A
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/d7719abd', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
#
#   los datos que obtenemos son:
#         fecha indicativo                nombre provincia  altitud  tmed  prec  \
# 0  2022-01-01      3266A  PUERTO ALTO DEL LEÓN    MADRID   1532.0  10.6   0.0
# 1  2022-01-02      3266A  PUERTO ALTO DEL LEÓN    MADRID   1532.0  10.4   0.0
# 2  2022-01-03      3266A  PUERTO ALTO DEL LEÓN    MADRID   1532.0   8.7   0.0
# 3  2022-01-04      3266A  PUERTO ALTO DEL LEÓN    MADRID   1532.0   3.9   3.3
# 4  2022-01-05      3266A  PUERTO ALTO DEL LEÓN    MADRID   1532.0  -1.4   4.9
#
#    tmin horatmin  tmax horatmax   dir  velmedia  racha horaracha  presMax  \
# 0   7.6    00:20  13.5    13:20  25.0       2.5    9.2     22:50    859.4
# 1   6.5    20:10  14.3    15:20  30.0       3.1    8.9     12:00    859.7
# 2   4.3    07:30  13.1    15:30  30.0       4.2   10.0     21:40    857.8
# 3  -1.9    23:59   9.7    01:50  30.0       8.1   26.1     16:10    850.8
# 4  -2.4    03:00  -0.5    14:00  30.0       1.7   16.1     00:20    846.2
#
#   horaPresMax  presMin horaPresMin   sol
# 0          09    858.0      Varias  None
# 1          10    857.7          16  None
# 2          00    850.8          24  None
# 3          00    838.0          17  None
# 4          11    842.8          21  None
# El codigo es:  3338
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/332e50a0', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
#
#   los datos que obtenemos son:
#         fecha indicativo              nombre provincia  altitud  tmed  tmin  \
# 0  2022-01-01       3338  ROBLEDO DE CHAVELA    MADRID    763.0  10.4   3.3
# 1  2022-01-02       3338  ROBLEDO DE CHAVELA    MADRID    763.0   9.9   3.7
# 2  2022-01-03       3338  ROBLEDO DE CHAVELA    MADRID    763.0   9.2   3.5
# 3  2022-01-04       3338  ROBLEDO DE CHAVELA    MADRID    763.0   7.7   3.9
# 4  2022-01-05       3338  ROBLEDO DE CHAVELA    MADRID    763.0   5.3   1.9
#
#   horatmin  tmax horatmax   dir  velmedia  racha horaracha  presMax  \
# 0    06:50  17.6    14:50  99.0       0.6    2.5    Varias    940.9
# 1    04:50  16.1    13:20  21.0       0.8    3.3     13:20    941.5
# 2    07:20  14.9    14:20  99.0       0.8    3.3    Varias    939.8
# 3    02:50  11.5    10:30  32.0       2.8   14.4     18:10    932.3
# 4    22:10   8.7    13:50  99.0       2.8   10.8    Varias    931.3
#
#   horaPresMax  presMin horaPresMin  prec   sol
# 0          10    938.8      Varias   NaN  None
# 1          10    939.0          16   NaN  None
# 2          00    932.3          24   NaN  None
# 3          00    922.5          15   NaN  None
# 4          11    926.3          21   NaN  None
# El codigo es:  3111D
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/2722304f', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
#
#   los datos que obtenemos son:
#         fecha indicativo      nombre provincia  altitud  tmed  prec  tmin  \
# 0  2022-01-01      3111D  SOMOSIERRA    MADRID   1450.0  10.2   0.0   5.0
# 1  2022-01-02      3111D  SOMOSIERRA    MADRID   1450.0  11.2   0.0   6.6
# 2  2022-01-03      3111D  SOMOSIERRA    MADRID   1450.0   9.3   0.0   4.3
# 3  2022-01-04      3111D  SOMOSIERRA    MADRID   1450.0   4.8  28.2  -1.4
# 4  2022-01-05      3111D  SOMOSIERRA    MADRID   1450.0  -1.4  11.5  -2.5
#
#   horatmin  tmax horatmax   dir  velmedia  racha horaracha presMax presMin  \
# 0    06:40  15.4    13:50  88.0       0.8    5.6     13:40    None    None
# 1    05:00  15.8    13:40  88.0       0.3    5.3     14:00    None    None
# 2    04:00  14.3    14:30  88.0       0.6    6.4     10:20    None    None
# 3    23:59  10.9    01:20  88.0       1.7   11.4     16:20    None    None
# 4    07:00  -0.2    13:50  88.0       0.0    0.0    Varias    None    None
#
#     sol
# 0  None
# 1  None
# 2  None
# 3  None
# 4  None
# El codigo es:  3175
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/79e86c36', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
#
#   los datos que obtenemos son:
#         fecha indicativo             nombre provincia  altitud  tmed  prec  \
# 0  2022-01-01       3175  TORREJÓN DE ARDOZ    MADRID    607.0   7.8   0.0
# 1  2022-01-02       3175  TORREJÓN DE ARDOZ    MADRID    607.0   7.5   0.0
# 2  2022-01-03       3175  TORREJÓN DE ARDOZ    MADRID    607.0   7.4   0.0
# 3  2022-01-04       3175  TORREJÓN DE ARDOZ    MADRID    607.0   6.4   6.0
# 4  2022-01-05       3175  TORREJÓN DE ARDOZ    MADRID    607.0   5.6   5.3
#
#    tmin horatmin  tmax horatmax   dir  velmedia  racha horaracha  sol  \
# 0  -1.3    07:30  17.0    14:10   2.0       1.1    5.6     18:50  8.2
# 1  -0.1    07:40  15.1    15:30   2.0       1.1    5.3     20:50  7.9
# 2   1.0    06:00  13.7    15:40  28.0       0.6    4.7     00:50  7.9
# 3  -0.1    04:30  12.8    14:10  29.0       1.7   17.5     16:10  1.2
# 4   1.7    23:59   9.6    13:50  26.0       1.7   10.8     15:40  5.1
#
#    presMax  presMin horaPresMax horaPresMin
# 0      NaN      NaN         NaN         NaN
# 1      NaN      NaN         NaN         NaN
# 2      NaN      NaN         NaN         NaN
# 3    952.9    938.1          00          15
# 4    948.5    944.3          11          21
#         fecha             Estacion Provincia  Temperatura_media  \
# 0  2022-01-01  ALBACETE BASE AÉREA  ALBACETE                9.4
# 1  2022-01-02  ALBACETE BASE AÉREA  ALBACETE                9.2
# 2  2022-01-03  ALBACETE BASE AÉREA  ALBACETE                9.0
# 3  2022-01-04  ALBACETE BASE AÉREA  ALBACETE               10.0
# 4  2022-01-05  ALBACETE BASE AÉREA  ALBACETE                6.0
#
#    Precipitacion_l_m3  Temperatura_minima  Temperatura_maxima  \
# 0                 0.0                -0.5                19.2
# 1                 0.0                 0.1                18.3
# 2                 0.0                -0.5                18.5
# 3                 0.4                 2.0                17.9
# 4                 0.8                 3.3                 8.8
#
#    Direccion_viento  Velocidad_media  Presion_maxima  Presion_minima  \
# 0              16.0              1.7           948.3           945.5
# 1              18.0              1.1           948.7           946.2
# 2              32.0              1.4           947.0           940.5
# 3              27.0              5.6           940.5           931.0
# 4              28.0              7.2           937.9           933.6
#
#    Prom_temperatura_media_prov  Grados_debajo_siete  Presion_externa
# 0                    10.158333                  0.0           946.90
# 1                     9.500000                  0.0           947.45
# 2                     8.750000                  0.0           943.75
# 3                     6.700000                  0.0           935.75
# 4                     3.833333                  1.0           935.75
#
#          fecha             Estacion Provincia  Temperatura_media  \
# 79  2022-03-21  ALBACETE BASE AÉREA  ALBACETE               11.4
# 80  2022-03-22  ALBACETE BASE AÉREA  ALBACETE                9.4
# 81  2022-03-23  ALBACETE BASE AÉREA  ALBACETE                8.2
# 82  2022-03-24  ALBACETE BASE AÉREA  ALBACETE               10.5
# 83  2022-03-25  ALBACETE BASE AÉREA  ALBACETE                9.8
#
#     Precipitacion_l_m3  Temperatura_minima  Temperatura_maxima  \
# 79                10.8                 8.4                14.5
# 80                 0.0                 7.2                11.7
# 81                 0.2                 7.1                 9.2
# 82                 0.0                 8.2                12.8
# 83                 0.8                 8.4                11.1
#
#     Direccion_viento  Velocidad_media  Presion_maxima  Presion_minima  \
# 79              11.0              4.7           940.0           936.8
# 80              10.0              6.7           941.5           938.9
# 81               7.0              7.8           940.9           936.7
# 82               9.0              6.9           938.2           935.9
# 83               6.0              7.5           937.1           932.9
#
#     Prom_temperatura_media_prov  Grados_debajo_siete  Presion_externa
# 79                     7.258333                  0.0           938.40
# 80                     6.300000                  0.0           940.20
# 81                     6.191667                  0.0           938.80
# 82                     6.775000                  0.0           937.05
# 83                     5.933333                  0.0           935.00
# Insertamos los datos...

# %% [markdown]
# El equipo ya ha conseguido investigar el funcionamiento de Google functions conjunto al Pubsub y Cloud scheduler.
#
# Así que vamos a proceder a subir parte del histórico que no subimos el día 30, es decir lo que se haya generado desde el día 25/03/2022 hasta el día de hoy - 1 dia.
#
# Vamos a proceder a dejejar un día de marjen para así elaborar el google function y comprobar que efectivamente sube los datos correctamente.

# %% [markdown]
# ## Importamos los paquetes del necesarios

# %%
from datetime import date
from datetime import timedelta

# %% [markdown]
# ## Importamos los paquetes que tienen que funcioanr en el requierements.txt de la función de interes

# %%
# !pip install pymysql
# Out:
# Looking in indexes: https://aws:****@ocsddna-112555760202.d.codeartifact.eu-west-1.amazonaws.com/pypi/ddna-mgmt/simple/
# Requirement already satisfied: pymysql in c:\users\kaiet.iglesias_bluet\desktop\virtual_envs\tfm\lib\site-packages (1.0.2)
# WARNING: You are using pip version 21.2.4; however, version 22.1 is available.
# You should consider upgrading via the 'C:\Users\kaiet.iglesias_bluet\Desktop\VIRTUAL_ENVS\TFM\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
import urllib3
import pandas as pd
import requests
import pymysql
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

# %% [markdown]
# # Vemos cual es el último dia que tenemos registros

# %%
import pymysql

host = '35.241.159.127'
user = 'admin'
password = '12345678'
database = 'GET_DATABASE'


connection = pymysql.connect(host=host,
                             user=user,
                             password=password,
                             db=database)

cursor = connection.cursor()



def run_query(q):
    with pymysql.connect(host=host,
                             user=user,
                             password=password,
                             db=database) as conn:
        return pd.read_sql(q, conn)

    
'''
Como en la semana de 28/03 se ha trabajado con las funciones de Google Functions y se está cargando la huedad en una 
nueva tabla vamos a utilizar la clausula de q1 para extraer la información  tal y como se hace en PowerBi.

'''


q = 'select * from METEREOLOGIA;'



sentencia = q


print(run_query(sentencia))
# Out:
# C:\Users\kaiet.iglesias_bluet\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#            fecha             Estacion Provincia  Temperatura_media  \
# 0     1998-01-01  ALBACETE BASE AÉREA  ALBACETE                  6
# 1     1998-01-02  ALBACETE BASE AÉREA  ALBACETE                  6
# 2     1998-01-03  ALBACETE BASE AÉREA  ALBACETE                 11
# 3     1998-01-04  ALBACETE BASE AÉREA  ALBACETE                 11
# 4     1998-01-05  ALBACETE BASE AÉREA  ALBACETE                  9
# ...          ...                  ...       ...                ...
# 9313  2022-03-25  ALBACETE BASE AÉREA  ALBACETE                 10
# 9314  2022-03-26  ALBACETE BASE AÉREA  ALBACETE                  9
# 9315  2022-03-26  ALBACETE BASE AÉREA  ALBACETE                  9
# 9316  2022-03-27  ALBACETE BASE AÉREA  ALBACETE                 10
# 9317  2022-03-28  ALBACETE BASE AÉREA  ALBACETE                  9
#
#       Precipitacion_l_m3  Temperatura_minima  Temperatura_maxima  \
# 0                      0                 2.4                 8.6
# 1                      0                 2.0                 9.8
# 2                      0                 7.2                15.2
# 3                      0                 9.2                13.1
# 4                      0                 3.0                15.0
# ...                  ...                 ...                 ...
# 9313                   1                 8.4                11.1
# 9314                   1                 7.6                10.1
# 9315                   1                 7.6                10.1
# 9316                   0                 5.2                14.5
# 9317                   0                 3.3                15.4
#
#      Direccion_viento  Velocidad_media  Presion_maxima  Presion_minima  \
# 0                 999            999.0           940.4           930.9
# 1                 999            999.0           941.8           939.2
# 2                 999            999.0           944.7           941.8
# 3                 999            999.0           943.5           941.6
# 4                 999            999.0           944.3           941.4
# ...               ...              ...             ...             ...
# 9313                6              7.5           937.1           932.9
# 9314                4              6.7           939.8           933.3
# 9315                4              6.7           939.8           933.3
# 9316               10              4.2           943.5           939.0
# 9317               15              3.9           942.5           934.6
#
#       Prom_temperatura_media_prov  Grados_debajo_siete  Presion_externa
# 0                          13.150                  1.5           935.65
# 1                          13.400                  1.1           940.50
# 2                          15.550                  0.0           943.25
# 3                          15.025                  0.0           942.55
# 4                           5.450                  0.0           942.85
# ...                           ...                  ...              ...
# 9313                        2.950                  0.0           935.00
# 9314                        0.875                  0.0           936.55
# 9315                        2.950                  0.0           936.55
# 9316                        0.875                  0.0           941.25
# 9317                        1.450                  0.0           938.55
#
# [9318 rows x 14 columns]

# %% [markdown]
# Vamos a exgtraer cual es el último dia

# %%
df = run_query(sentencia)

import datetime

from datetime import date
from datetime import timedelta


last_day = df.iloc[df.shape[0]-1,0].strftime('%Y-%m-%d')

#sacamos el dia de hoy 
today = date.today()


print('El último dia: ', last_day, ' y hoy es ', str(today))
# Out:
# C:\Users\kaiet.iglesias_bluet\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# El último dia:  2022-03-28  y hoy es  2022-05-19

# %% [markdown]
# Vamos a extraer la información entre esas dos fechas

# %%
df = mi_metereologia(8175,last_day,  str(today),'eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJraWdsZXNpYXNiYXJhaWJhckBzdHVkZW50LmVhZS5lcyIsImp0aSI6ImY4YWQ5OGRmLTkzMjQtNDEzMi05NjY3LTdjY2E2Nzc3Mzc0NiIsImlzcyI6IkFFTUVUIiwiaWF0IjoxNjQyOTYzODc0LCJ1c2VySWQiOiJmOGFkOThkZi05MzI0LTQxMzItOTY2Ny03Y2NhNjc3NzM3NDYiLCJyb2xlIjoiIn0.en7xw4HHYaZ4oW8qooX6wGG3yn1Tv3OzFfnhrZac6vo', provincia = 'ALBACETE')
    
    #Se reemplazan los nas por 999

df = df.fillna(999)

    #print(df.head())


  #-------- SUBIMOS LOS DATOS --------#

print(df.head() , "\n")
# Out:
# Se ha extraido la información de AEMET
# El codigo es:  7096B
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/a874dda1', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
#
#   los datos que obtenemos son:
#         fecha indicativo  nombre provincia  altitud  tmed  prec  tmin  \
# 0  2022-03-28      7096B  HELLÍN  ALBACETE    646.0   9.2   0.0   5.9
# 1  2022-03-29      7096B  HELLÍN  ALBACETE    646.0  12.8   0.1   7.7
# 2  2022-03-30      7096B  HELLÍN  ALBACETE    646.0  11.0   4.5   8.5
# 3  2022-03-31      7096B  HELLÍN  ALBACETE    646.0  10.6   0.4   7.9
# 4  2022-04-01      7096B  HELLÍN  ALBACETE    646.0   8.0   0.1   4.5
#
#   horatmin  tmax horatmax   dir  velmedia  racha horaracha  presMax  \
# 0    02:00  12.5    16:00  24.0       2.2    5.6     15:10    954.3
# 1    06:00  17.9    13:00   9.0       2.8    8.1     12:40    947.0
# 2    23:59  13.4    11:30   4.0       1.1   12.2     22:20    936.1
# 3    01:00  13.3    17:00  24.0       3.9   12.8     16:50    938.1
# 4    23:59  11.6    14:40  33.0       5.3   13.6     09:10    947.0
#
#   horaPresMax  presMin horaPresMin   sol
# 0          00    946.4          23  None
# 1          00    935.7          16  None
# 2          00    932.2          17  None
# 3          24    934.6          03  None
# 4          24    937.8      Varias  None
# El codigo es:  8175
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/27f16d28', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
#
#   los datos que obtenemos son:
#         fecha indicativo               nombre provincia  altitud  tmed  prec  \
# 0  2022-03-28       8175  ALBACETE BASE AÉREA  ALBACETE    702.0   9.4   0.0
# 1  2022-03-29       8175  ALBACETE BASE AÉREA  ALBACETE    702.0  11.2   3.6
# 2  2022-03-30       8175  ALBACETE BASE AÉREA  ALBACETE    702.0  10.0   5.2
# 3  2022-03-31       8175  ALBACETE BASE AÉREA  ALBACETE    702.0   9.2   0.4
# 4  2022-04-01       8175  ALBACETE BASE AÉREA  ALBACETE    702.0   6.6   0.0
#
#    tmin horatmin  tmax horatmax   dir  velmedia  racha horaracha  sol  \
# 0   3.3    01:50  15.4    14:00  15.0       3.9   10.8     11:10  2.4
# 1   5.9    06:20  16.4    16:10  28.0       2.8    7.8     16:20  3.1
# 2   7.2    23:40  12.7    13:10  99.0       2.5   10.0    Varias  NaN
# 3   5.5    23:59  13.0    12:20  29.0       6.9   16.4     13:10  8.1
# 4   1.3    23:59  11.8    15:40  32.0       6.1   15.8     12:30  9.6
#
#    presMax horaPresMax  presMin horaPresMin
# 0    942.5          00    934.6          24
# 1    935.0          00    924.8      Varias
# 2    925.1          00    921.0      Varias
# 3    926.5          24    923.5      Varias
# 4    935.5          24    926.5          00
# El codigo es:  8178D
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/539bd3b3', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
#
#   los datos que obtenemos son:
#         fecha indicativo    nombre provincia  altitud  tmed  prec  tmin  \
# 0  2022-03-28      8178D  ALBACETE  ALBACETE    676.0  10.4   0.2   5.3
# 1  2022-03-29      8178D  ALBACETE  ALBACETE    676.0  11.3   2.0   6.5
# 2  2022-03-30      8178D  ALBACETE  ALBACETE    676.0  10.2  20.5   7.2
# 3  2022-03-31      8178D  ALBACETE  ALBACETE    676.0   9.6   0.2   6.0
# 4  2022-04-01      8178D  ALBACETE  ALBACETE    676.0   6.8   0.0   1.8
#
#   horatmin  tmax horatmax   dir  velmedia  racha horaracha   sol  presMax  \
# 0    00:36  15.4    14:50  12.0       1.4    7.5     13:00   2.9    947.2
# 1    06:10  16.1    16:12   9.0       0.6    7.5     02:10   2.6    939.7
# 2    23:40  13.1    13:23  27.0       0.3   14.7     14:37   0.0    929.7
# 3    04:34  13.1    14:04  29.0       1.4   11.9     15:44   8.9    931.0
# 4    23:50  11.7    14:40  25.0       1.1   12.2     14:00  10.0    940.1
#
#   horaPresMax  presMin horaPresMin
# 0          00    939.7          24
# 1          00    929.5          17
# 2          00    925.5          18
# 3          24    928.2          03
# 4          24    931.0          00
# El codigo es:  8177A
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/a93ef980', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
#
#   los datos que obtenemos son:
#         fecha indicativo      nombre provincia  altitud  tmed  prec  tmin  \
# 0  2022-03-28      8177A  CHINCHILLA  ALBACETE    880.0   7.2   0.0   1.6
# 1  2022-03-29      8177A  CHINCHILLA  ALBACETE    880.0   9.6   1.8   4.2
# 2  2022-03-30      8177A  CHINCHILLA  ALBACETE    880.0   7.2  15.1   4.7
# 3  2022-03-31      8177A  CHINCHILLA  ALBACETE    880.0   6.7   0.3   3.1
# 4  2022-04-01      8177A  CHINCHILLA  ALBACETE    880.0   4.0   0.0  -0.6
#
#   horatmin  tmax horatmax   dir  velmedia  racha horaracha  presMax  \
# 0    02:40  12.9    13:50  11.0       5.0   11.9     09:50    921.7
# 1    05:40  14.9    12:20  12.0       2.2    7.8     02:10    915.0
# 2    23:59   9.7    13:40  30.0       2.8   11.7     19:50    905.5
# 3    05:50  10.3    12:30  30.0       5.3   15.0     14:50    906.3
# 4    23:59   8.5    14:30  32.0       6.4   15.6     11:00    914.0
#
#   horaPresMax  presMin horaPresMin   sol
# 0          00    914.5          24  None
# 1          00    905.5          24  None
# 2          00    901.4      Varias  None
# 3          22    903.1          02  None
# 4          22    906.1          00  None
#         fecha             Estacion Provincia  Temperatura_media  \
# 0  2022-03-28  ALBACETE BASE AÉREA  ALBACETE                9.4
# 1  2022-03-29  ALBACETE BASE AÉREA  ALBACETE               11.2
# 2  2022-03-30  ALBACETE BASE AÉREA  ALBACETE               10.0
# 3  2022-03-31  ALBACETE BASE AÉREA  ALBACETE                9.2
# 4  2022-04-01  ALBACETE BASE AÉREA  ALBACETE                6.6
#
#    Precipitacion_l_m3  Temperatura_minima  Temperatura_maxima  \
# 0                 0.0                 3.3                15.4
# 1                 3.6                 5.9                16.4
# 2                 5.2                 7.2                12.7
# 3                 0.4                 5.5                13.0
# 4                 0.0                 1.3                11.8
#
#    Direccion_viento  Velocidad_media  Presion_maxima  Presion_minima  \
# 0              15.0              3.9           942.5           934.6
# 1              28.0              2.8           935.0           924.8
# 2              99.0              2.5           925.1           921.0
# 3              29.0              6.9           926.5           923.5
# 4              32.0              6.1           935.5           926.5
#
#    Prom_temperatura_media_prov  Grados_debajo_siete  Presion_externa
# 0                        9.050                  0.0           938.55
# 1                       11.225                  0.0           929.90
# 2                        9.600                  0.0           923.05
# 3                        9.025                  0.0           925.00
# 4                        6.350                  0.4           931.00

# %% [markdown]
# No queremos subir todos los datos sino no tenemos margen para subir los del último dia y comprobar la función por lo que subiremos solo las dos primeras filas

# %% [markdown]
# #fecha impiutada a mano
#
# fecha_ahora = '2022-03-26'
#
#
# '''
# df = mi_metereologia(8175,last_day, str(fecha_ahora) ,'eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJraWdsZXNpYXNiYXJhaWJhckBzdHVkZW50LmVhZS5lcyIsImp0aSI6ImY4YWQ5OGRmLTkzMjQtNDEzMi05NjY3LTdjY2E2Nzc3Mzc0NiIsImlzcyI6IkFFTUVUIiwiaWF0IjoxNjQyOTYzODc0LCJ1c2VySWQiOiJmOGFkOThkZi05MzI0LTQxMzItOTY2Ny03Y2NhNjc3NzM3NDYiLCJyb2xlIjoiIn0.en7xw4HHYaZ4oW8qooX6wGG3yn1Tv3OzFfnhrZac6vo', provincia = 'ALBACETE')
# '''
#
#
#
# df = mi_metereologia(8175,last_day,  ¡,'eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJraWdsZXNpYXNiYXJhaWJhckBzdHVkZW50LmVhZS5lcyIsImp0aSI6ImY4YWQ5OGRmLTkzMjQtNDEzMi05NjY3LTdjY2E2Nzc3Mzc0NiIsImlzcyI6IkFFTUVUIiwiaWF0IjoxNjQyOTYzODc0LCJ1c2VySWQiOiJmOGFkOThkZi05MzI0LTQxMzItOTY2Ny03Y2NhNjc3NzM3NDYiLCJyb2xlIjoiIn0.en7xw4HHYaZ4oW8qooX6wGG3yn1Tv3OzFfnhrZac6vo', provincia = 'ALBACETE')
#
# df = df.fillna(999)
#
#     #print(df.head())
#
#
#   #-------- SUBIMOS LOS DATOS --------#
#
# print(df.head() , "\n")

# %% [markdown]
# Es correcto hacemos la subida

# %%
print('Insertamos los datos...')



insert_into(df, 'METEREOLOGIA')
# Out:
# Insertamos los datos...

# %% [markdown]
# Comprobamos que se han subido los datos historicos

# %%
q = 'select * from METEREOLOGIA where Temperatura_media  < 1000;'



sentencia = q



print(run_query(sentencia))
# Out:
# C:\Users\kaiet.iglesias_bluet\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#            fecha             Estacion Provincia  Temperatura_media  \
# 0     1998-01-01  ALBACETE BASE AÉREA  ALBACETE                  6
# 1     1998-01-02  ALBACETE BASE AÉREA  ALBACETE                  6
# 2     1998-01-03  ALBACETE BASE AÉREA  ALBACETE                 11
# 3     1998-01-04  ALBACETE BASE AÉREA  ALBACETE                 11
# 4     1998-01-05  ALBACETE BASE AÉREA  ALBACETE                  9
# ...          ...                  ...       ...                ...
# 9362  2022-05-11  ALBACETE BASE AÉREA  ALBACETE                 19
# 9363  2022-05-12  ALBACETE BASE AÉREA  ALBACETE                 17
# 9364  2022-05-13  ALBACETE BASE AÉREA  ALBACETE                 20
# 9365  2022-05-14  ALBACETE BASE AÉREA  ALBACETE                 21
# 9366  2022-05-15  ALBACETE BASE AÉREA  ALBACETE                 20
#
#       Precipitacion_l_m3  Temperatura_minima  Temperatura_maxima  \
# 0                      0                 2.4                 8.6
# 1                      0                 2.0                 9.8
# 2                      0                 7.2                15.2
# 3                      0                 9.2                13.1
# 4                      0                 3.0                15.0
# ...                  ...                 ...                 ...
# 9362                   0                11.1                26.2
# 9363                   0                 8.4                25.0
# 9364                   0                10.0                29.5
# 9365                   0                14.1                28.6
# 9366                   0                11.6                29.4
#
#      Direccion_viento  Velocidad_media  Presion_maxima  Presion_minima  \
# 0                 999            999.0           940.4           930.9
# 1                 999            999.0           941.8           939.2
# 2                 999            999.0           944.7           941.8
# 3                 999            999.0           943.5           941.6
# 4                 999            999.0           944.3           941.4
# ...               ...              ...             ...             ...
# 9362               12              5.0           940.6           938.0
# 9363               13              4.4           940.7           938.2
# 9364               16              2.5           941.1           938.3
# 9365               12              5.6           939.2           934.9
# 9366               26              2.2           939.0           935.2
#
#       Prom_temperatura_media_prov  Grados_debajo_siete  Presion_externa
# 0                          13.150                  1.5           935.65
# 1                          13.400                  1.1           940.50
# 2                          15.550                  0.0           943.25
# 3                          15.025                  0.0           942.55
# 4                           5.450                  0.0           942.85
# ...                           ...                  ...              ...
# 9362                       18.150                  0.0           939.30
# 9363                       16.700                  0.0           939.45
# 9364                       19.900                  0.0           939.70
# 9365                       20.150                  0.0           937.05
# 9366                       20.325                  0.0           937.10
#
# [9367 rows x 14 columns]

# %% [markdown]
# Visualmente hablando:

# %%
import matplotlib.pyplot as plt

datos_humedad_historico = run_query(sentencia)
# Out:
# C:\Users\kaiet.iglesias_bluet\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
humedad_media_dia =  pd.pivot_table(datos_humedad_historico, values='Temperatura_media' , index='fecha')

#hacemos un filtrado de seguridad

humedad_media_dia = humedad_media_dia[humedad_media_dia['Temperatura_media'] < 400]

#vemos la imagen

humedad_media_dia['Temperatura_media'].plot()
plt.title('Evolución de la temperatura ')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ## Creación de datos temporales
#
# Imporamos algunos paquetes y tal antes de pasar el script a Python y ponerlo en
# producción en Google Functions

# %%
import datetime

from datetime import date
from datetime import timedelta


#sacamos el dia de hoy 
today = date.today()

#sacamos la información desde hace 4 dias hasta hace 2 dias
hace_dos = today - timedelta(days = 2)
hace_cuatro  = hace_dos - timedelta(days = 2)


last_day = df.iloc[(df.shape[0]-1),0]


print('HOY ES: ', today, ' antes de ayer era ', hace_dos, ' y  antes antes de ayer ', hace_cuatro)

print('\n y el último registro lo tenemos del día : ', last_day)
# Out:
# HOY ES:  2022-05-19  antes de ayer era  2022-05-17  y  antes antes de ayer  2022-05-15
#
#  y el último registro lo tenemos del día :  2022-05-15

# %% [markdown]
# Entonces los datos que tenemo que extraer son desde el 26 hasta... un today, que es siempre el dinamico es decir:

# %%
'''
1) Así que primero habrá que hacer una call a la base de datos y sacar la 
fecha del último registro

'''
import urllib3
import pandas as pd
import requests
import datetime
from datetime import date
from datetime import timedelta
import pymysql
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)


import pymysql

host = '35.241.159.127'
user = 'admin'
password = '12345678'
database = 'GET_DATABASE'


connection = pymysql.connect(host=host,
                             user=user,
                             password=password,
                             db=database)

cursor = connection.cursor()



def run_query(q):
    with pymysql.connect(host=host,
                             user=user,
                             password=password,
                             db=database) as conn:
        return pd.read_sql(q, conn)

    
'''
Como en la semana de 28/03 se ha trabajado con las funciones de Google Functions y se está cargando la huedad en una 
nueva tabla vamos a utilizar la clausula de q1 para extraer la información  tal y como se hace en PowerBi.

'''


q = 'select * from METEREOLOGIA;'



sentencia = q

df = run_query(sentencia)

last_day = df.iloc[(df.shape[0]-1),0]





'''
2) Luego tendremos que calcular cual es el día de hoy 

'''

today = date.today()

print('Sacando datos de AEMET entre los días :',  last_day, ' y ', today)


'''
3) Hariamos la consulta 

'''

df = mi_metereologia(8175,last_day,  str(today), 'eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJraWdsZXNpYXNiYXJhaWJhckBzdHVkZW50LmVhZS5lcyIsImp0aSI6ImY4YWQ5OGRmLTkzMjQtNDEzMi05NjY3LTdjY2E2Nzc3Mzc0NiIsImlzcyI6IkFFTUVUIiwiaWF0IjoxNjQyOTYzODc0LCJ1c2VySWQiOiJmOGFkOThkZi05MzI0LTQxMzItOTY2Ny03Y2NhNjc3NzM3NDYiLCJyb2xlIjoiIn0.en7xw4HHYaZ4oW8qooX6wGG3yn1Tv3OzFfnhrZac6vo')
    
    #Se reemplazan los nas por 999

df = df.fillna(999)

    #print(df.head())


  #-------- SUBIMOS LOS DATOS --------#

print(df.head() , "\n")



#4) Y finalmente lo subiriamos pero no lo hacemos aquí sino que lo vamos a hacer
#con un archivo python en 
#SERVERLESS_DEPLOYMENT/Google Funcions/FUNCION_METEREOLOGIA_MAS
# Out:
# C:\Users\kaiet.iglesias_bluet\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# Sacando datos de AEMET entre los días : 2022-05-15  y  2022-05-19
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [22], in <cell line: 77>()
#      69 print('Sacando datos de AEMET entre los días :',  last_day, ' y ', today)
#      72 '''
#      73 3) Hariamos la consulta
#      74
#      75 '''
# ---> 77 df = mi_metereologia(8175,last_day,  str(today), 'eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJraWdsZXNpYXNiYXJhaWJhckBzdHVkZW50LmVhZS5lcyIsImp0aSI6ImY4YWQ5OGRmLTkzMjQtNDEzMi05NjY3LTdjY2E2Nzc3Mzc0NiIsImlzcyI6IkFFTUVUIiwiaWF0IjoxNjQyOTYzODc0LCJ1c2VySWQiOiJmOGFkOThkZi05MzI0LTQxMzItOTY2Ny03Y2NhNjc3NzM3NDYiLCJyb2xlIjoiIn0.en7xw4HHYaZ4oW8qooX6wGG3yn1Tv3OzFfnhrZac6vo')
#      79     #Se reemplazan los nas por 999
#      81 df = df.fillna(999)
#
# TypeError: mi_metereologia() missing 1 required positional argument: 'provincia'

# %% [markdown]
# Seguimos con la lógica de negocio en la carpeta SERVERLESS_DEPLOYMENT/Google Funcions/FUNCION_METEREOLOGIA_MAS
