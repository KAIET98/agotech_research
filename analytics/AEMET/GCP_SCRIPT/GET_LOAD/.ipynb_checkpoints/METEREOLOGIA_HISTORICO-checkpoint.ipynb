# %% [markdown]
# <a href="https://colab.research.google.com/github/KAIET98/TFM_AGROTECH/blob/develop/analytics/AEMET/GCP_SCRIPT/METEREOLOGIA_HISTORICO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''
Importamos este paquete para eliminar los warnings que nos pueda llegar a generar l afuncioón

'''
import urllib3
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)


'''
Este script tiene como objetvio automatizar la captación de todos los datos metereologicos
de una estación cualquiera de españa que se le proporcione
'''


from metereology.metereology import mi_metereologia

# %%
# !pip install pymysql
# Out:
# Requirement already satisfied: pymysql in /home/bluetab/anaconda3/lib/python3.9/site-packages (1.0.2)

# %%
#El objetivo de esta función es la construcción de una función que sirva para insertar 
#lineas en una tabla de sql.

import pandas as pd
import numpy as np
import pymysql
#import cryptography
import pandas as pd

'''
------------------- AWS OLD CONNECTION --------------
host = 'database-1.cq2dp4jmizro.eu-west-1.rds.amazonaws.com'
user = 'admin'
password = '12345678'
database = 'GET_DATABASE'

'''
#----------------------- GCP connection-----------------

host = '35.241.159.127' #este el el host nuevo
user = 'admin'
password = '12345678'
database = 'GET_DATABASE'

def insert_into(data, arrival_df):

    #establecemos la conexión a la base de datos
    connection = pymysql.connect(host=host,
                             user=user,
                             password=password,
                             db=database)

    cursor = connection.cursor()


    #especificamos cual es el nombre de la tabla destino

    nombre_tabla = arrival_df

    
    # creating column list for insertion
    cols = "`,`".join([str(i) for i in data.columns.tolist()])
    cols = cols.strip()
    # Insert DataFrame recrds one by one.
    for i,row in data.iterrows():
        sql = "INSERT INTO `{}` (`".format(nombre_tabla) +cols + "`) VALUES (" + "%s,"*(len(row)-1) + "%s)"

            
        cursor.execute(sql, tuple(row))

            # the connection is not autocommitted by default, so we must commit to save our changes
        connection.commit()

# %%
import logging
import requests
import pymysql

host = '34.175.164.167' #este el el host nuevo
user = 'admin'
password = '12345678'
database = 'GET_DATABASE'




'''
def conectame(host, user, password, database):

    #conn = pymysql.connect(host=host, user=user, password=password, port=3306, db='GET_DATABASE',charset='utf8')

    connection = pymysql.connect(host=host,
                                user=user,
                                password=password,
                                db=database)

    cursor = connection.cursor()

    return cursor
cursor = conectame(host, user, password, database)
'''

logger = logging.getLogger()
logger.setLevel(logging.INFO)

try:
    conn = pymysql.connect(host=host, user=user, passwd=password, db=database, connect_timeout=5)
except pymysql.MySQLError as e:
    logger.error("ERROR: Unexpected error: Could not connect to MySQL instance.")
    logger.error(e)
    sys.exit()

logger.info("SUCCESS: Connection to RDS MySQL instance succeeded")

#------------------ creamos la tabla ---------------

def run_query(q):
  with pymysql.connect(host=host,
                             user=user,
                             password=password,
                             db=database) as conn:
                             return pd.read_sql(q, conn)



def checkTableExists(conn, tablename):
    dbcur = conn.cursor()
    dbcur.execute("""
        SELECT COUNT(*)
        FROM information_schema.tables
        WHERE table_name = '{0}'
        """.format(tablename.replace('\'', '\'\'')))
    if dbcur.fetchone()[0] == 1:
        dbcur.close()
        return True

    dbcur.close()
    return False

#------------ ESPECIFICAMOS CUAL VA A SER LA TABLA DE INTERÉS------

tabla_de_interes = 'METEREOLOGIA'

coordenadas = (39.55678333333333, -3.1920416666666664) #https://www.vercalendario.info/es/como/convertir-latitud-longitud-grados-decimales.html#:~:text=Latitud%2038%C2%B054%E2%80%B2%2017%E2%80%B3N%20equivale%20a%2038.90472222222222%C2%B0,77.01638888888888%C2%B0%20(Grados%20decimales).

API_AEMET = 'eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJraWdsZXNpYXNiYXJhaWJhckBzdHVkZW50LmVhZS5lcyIsImp0aSI6ImY4YWQ5OGRmLTkzMjQtNDEzMi05NjY3LTdjY2E2Nzc3Mzc0NiIsImlzcyI6IkFFTUVUIiwiaWF0IjoxNjQyOTYzODc0LCJ1c2VySWQiOiJmOGFkOThkZi05MzI0LTQxMzItOTY2Ny03Y2NhNjc3NzM3NDYiLCJyb2xlIjoiIn0.en7xw4HHYaZ4oW8qooX6wGG3yn1Tv3OzFfnhrZac6vo'
API_GOOGLE = 'AIzaSyD7zvwwj8-4JS2XZq0n8bLb9t2cSqStx84'


#2014
if checkTableExists(conn, tabla_de_interes):
    
    for ano in range(2010, 2023):
    
        print('\n ######################### \n')

        print('Subiendo los datos del año; ', ano)


          #-------- HACEMOS EL SCRAPPING ----------


        #ano = 1998

        #df = mi_metereologia(8175, '{}-01-01'.format(ano), '{}-12-31'.format(ano), 'eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJraWdsZXNpYXNiYXJhaWJhckBzdHVkZW50LmVhZS5lcyIsImp0aSI6ImY4YWQ5OGRmLTkzMjQtNDEzMi05NjY3LTdjY2E2Nzc3Mzc0NiIsImlzcyI6IkFFTUVUIiwiaWF0IjoxNjQyOTYzODc0LCJ1c2VySWQiOiJmOGFkOThkZi05MzI0LTQxMzItOTY2Ny03Y2NhNjc3NzM3NDYiLCJyb2xlIjoiIn0.en7xw4HHYaZ4oW8qooX6wGG3yn1Tv3OzFfnhrZac6vo')

          #Se reemplazan los nas por 999


        mi_metereologia_clase = mi_metereologia( google_maps_key = API_GOOGLE,\
            coodenadas = coordenadas,\
            api_aemet =  API_AEMET,\
            fecha_ini = '{}-01-01'.format(ano),\
            fecha_fin = '{}-12-31'.format(ano))


        #Sacamos que provincia me corresponde con la ubicacion que he pasado

        provincia =  mi_metereologia_clase.address()



        #Sacamos las esatciones de dicha provincia

        estaciones_provincia = mi_metereologia_clase.estaciones()

        print(estaciones_provincia)

        #Extraigo mi latitud y longitud
        mi_ubicacion = mi_metereologia_clase.mi_latlon()




        #Sacamos la distancias que tengo a las estaciones de mi alrededor

        mis_estaciones_distancias_brutas = mi_metereologia_clase.distancias()




        #estaciones_provincia['distancia'] = mis_estaciones_distancias_brutas


        #Falta sacar la estacion más cercana


        estaciones_ordenadas = mi_metereologia_clase.ordenar_distancias(mis_estaciones_distancias_brutas)

        estacion_mas_cercana_codigo = mi_metereologia_clase.mis_estaciones_mas_cercanas(estaciones_provincia, estaciones_ordenadas)


        #print(estacion_mas_cercana_codigo)

        #hacer la llamada a la api de aemet


        #mis_datos = mi_metereologia_clase.meterelogia_estacion_mas_cercana()


        #print(mis_datos.head())

        df = mi_metereologia_clase.meterelogia_estacion_mas_cercana()

        df = df.fillna(999)


        print(df.head())
          #print(df.head())


          #-------- SUBIMOS LOS DATOS --------#

        insert_into(df, 'METEREOLOGIA')
    



   
  
  
else:
    
  q = '''CREATE TABLE METEREOLOGIA(

    fecha   DATE NOT NULL, 
    Estacion VARCHAR(255) NOT NULL, 
    Provincia VARCHAR(255), 
    Temperatura_media INT,
    Precipitacion_l_m3 INT, 
        Temperatura_minima float, 
        Temperatura_maxima float,
        Direccion_viento VARCHAR(255), 
        Velocidad_media float, 
        Presion_maxima float,
          Presion_minima float, 
          Prom_temperatura_media_prov float, 
          Grados_debajo_siete float,
          Presion_externa float
          
          );'''


  print(run_query(q))
# Out:
#  #########################
#
# Subiendo los datos del año;  2010
# Busqueda por coordenadas
# address_components
# address_components es una lista
# formatted_address
# formatted_address es una lista
# geometry
# geometry es una lista
# place_id
# place_id es una lista
# plus_code
# plus_code es una lista
# types
# types es una lista
# la provincia es:  Castile-La Mancha
# Tenemos info geolocalizada :)
#  39.55678330000001 ,  -3.1920417
#  ... it is possible to extract the province information ...
#  ... province obtained ...
#  the province is: Toledo
# Provincia optenida :)
#  TOLEDO
# ['BARCELONA' 'GIRONA' 'TARRAGONA' 'A CORUÑA' 'ASTURIAS' 'BIZKAIA'
#  'CANTABRIA' 'GIPUZKOA' 'LEON' 'LUGO' 'NAVARRA' 'OURENSE' 'PONTEVEDRA'
#  'AVILA' 'BURGOS' 'MADRID' 'PALENCIA' 'SALAMANCA' 'SEGOVIA' 'SORIA'
#  'VALLADOLID' 'ZAMORA' 'CACERES' 'CUENCA' 'GUADALAJARA' 'TOLEDO' 'BADAJOZ'
#  'CIUDAD REAL' 'CORDOBA' 'HUELVA' 'CADIZ' 'CEUTA' 'GRANADA' 'JAEN'
#  'SEVILLA' 'ALMERIA' 'MALAGA' 'MELILLA' 'ALBACETE' 'ALICANTE' 'MURCIA'
#  'CASTELLON' 'TERUEL' 'VALENCIA' 'ARABA/ALAVA' 'HUESCA' 'LA RIOJA'
#  'LLEIDA' 'ZARAGOZA' 'ILLES BALEARS' 'LAS PALMAS' 'STA. CRUZ DE TENERIFE']
#                   Estacion  latitud_of  longitud_of indicativo
# 0  SAN PABLO DE LOS MONTES   39.546944    -4.350556      3298X
# 1     TALAVERA DE LA REINA   39.958611    -4.863611      3365A
# 2        TOLEDO, LORENZANA   39.859444    -4.025556       3259
# 3                   TOLEDO   39.884722    -4.045278      3260B
# 4               MADRIDEJOS   39.491944    -3.528333       4067
# 5    QUINTANAR DE LA ORDEN   39.597500    -3.046944      4061X
#  El codigo en cuestion  200
#
#  La url que vamos a gestionar es:  https://opendata.aemet.es/opendata/sh/618f3f46
#
#         fecha               Estacion Provincia  Temperatura_media  \
# 0  2010-01-09  QUINTANAR DE LA ORDEN    TOLEDO                999
# 1  2010-01-10  QUINTANAR DE LA ORDEN    TOLEDO                999
# 2  2010-01-14  QUINTANAR DE LA ORDEN    TOLEDO                999
# 3  2010-01-17  QUINTANAR DE LA ORDEN    TOLEDO                999
# 4  2010-01-18  QUINTANAR DE LA ORDEN    TOLEDO                999
#
#    Precipitacion_l_m3  Temperatura_minima  Temperatura_maxima  \
# 0                 0.0                 999                 999
# 1                 8.7                 999                 999
# 2                 0.0                 999                 999
# 3                 0.0                 999                 999
# 4                 0.0                 999                 999
#
#    Direccion_viento  Velocidad_media  Presion_maxima  Presion_minima  \
# 0               999              999             999             999
# 1               999              999             999             999
# 2               999              999             999             999
# 3               999              999             999             999
# 4               999              999             999             999
#
#    Prom_temperatura_media_prov  Grados_debajo_siete  Presion_externa
# 0                          0.0                    0              999
# 1                          0.0                    0              999
# 2                          0.0                    0              999
# 3                          0.0                    0              999
# 4                          0.0                    0              999
#
#  #########################
#
# Subiendo los datos del año;  2011
# Busqueda por coordenadas
# address_components
# address_components es una lista
# formatted_address
# formatted_address es una lista
# geometry
# geometry es una lista
# place_id
# place_id es una lista
# plus_code
# plus_code es una lista
# types
# types es una lista
# la provincia es:  Castile-La Mancha
# Tenemos info geolocalizada :)
#  39.55678330000001 ,  -3.1920417
#  ... it is possible to extract the province information ...
#  ... province obtained ...
#  the province is: Toledo
# Provincia optenida :)
#  TOLEDO
# ['BARCELONA' 'GIRONA' 'TARRAGONA' 'A CORUÑA' 'ASTURIAS' 'BIZKAIA'
#  'CANTABRIA' 'GIPUZKOA' 'LEON' 'LUGO' 'NAVARRA' 'OURENSE' 'PONTEVEDRA'
#  'AVILA' 'BURGOS' 'MADRID' 'PALENCIA' 'SALAMANCA' 'SEGOVIA' 'SORIA'
#  'VALLADOLID' 'ZAMORA' 'CACERES' 'CUENCA' 'GUADALAJARA' 'TOLEDO' 'BADAJOZ'
#  'CIUDAD REAL' 'CORDOBA' 'HUELVA' 'CADIZ' 'CEUTA' 'GRANADA' 'JAEN'
#  'SEVILLA' 'ALMERIA' 'MALAGA' 'MELILLA' 'ALBACETE' 'ALICANTE' 'MURCIA'
#  'CASTELLON' 'TERUEL' 'VALENCIA' 'ARABA/ALAVA' 'HUESCA' 'LA RIOJA'
#  'LLEIDA' 'ZARAGOZA' 'ILLES BALEARS' 'LAS PALMAS' 'STA. CRUZ DE TENERIFE']
#                   Estacion  latitud_of  longitud_of indicativo
# 0  SAN PABLO DE LOS MONTES   39.546944    -4.350556      3298X
# 1     TALAVERA DE LA REINA   39.958611    -4.863611      3365A
# 2        TOLEDO, LORENZANA   39.859444    -4.025556       3259
# 3                   TOLEDO   39.884722    -4.045278      3260B
# 4               MADRIDEJOS   39.491944    -3.528333       4067
# 5    QUINTANAR DE LA ORDEN   39.597500    -3.046944      4061X
#  El codigo en cuestion  200
#
#  La url que vamos a gestionar es:  https://opendata.aemet.es/opendata/sh/85044947
#
#         fecha               Estacion Provincia  Temperatura_media  \
# 0  2011-01-01  QUINTANAR DE LA ORDEN    TOLEDO                999
# 1  2011-01-02  QUINTANAR DE LA ORDEN    TOLEDO                999
# 2  2011-01-03  QUINTANAR DE LA ORDEN    TOLEDO                999
# 3  2011-01-04  QUINTANAR DE LA ORDEN    TOLEDO                999
# 4  2011-01-05  QUINTANAR DE LA ORDEN    TOLEDO                999
#
#    Precipitacion_l_m3  Temperatura_minima  Temperatura_maxima  \
# 0                 0.0                 999                 999
# 1                 0.0                 999                 999
# 2                 0.0                 999                 999
# 3                 0.2                 999                 999
# 4                 1.8                 999                 999
#
#    Direccion_viento  Velocidad_media  Presion_maxima  Presion_minima  \
# 0               999              999           999.0           999.0
# 1               999              999           999.0           999.0
# 2               999              999           999.0           999.0
# 3               999              999           999.0           999.0
# 4               999              999           999.0           999.0
#
#    Prom_temperatura_media_prov  Grados_debajo_siete  Presion_externa
# 0                          0.0                    0            999.0
# 1                          0.0                    0            999.0
# 2                          0.0                    0            999.0
# 3                          0.0                    0            999.0
# 4                          0.0                    0            999.0
#
#  #########################
#
# Subiendo los datos del año;  2012
# Busqueda por coordenadas
# address_components
# address_components es una lista
# formatted_address
# formatted_address es una lista
# geometry
# geometry es una lista
# place_id
# place_id es una lista
# plus_code
# plus_code es una lista
# types
# types es una lista
# la provincia es:  Castile-La Mancha
# Tenemos info geolocalizada :)
#  39.55678330000001 ,  -3.1920417
#  ... it is possible to extract the province information ...
#  ... province obtained ...
#  the province is: Toledo
# Provincia optenida :)
#  TOLEDO
# ['BARCELONA' 'GIRONA' 'TARRAGONA' 'A CORUÑA' 'ASTURIAS' 'BIZKAIA'
#  'CANTABRIA' 'GIPUZKOA' 'LEON' 'LUGO' 'NAVARRA' 'OURENSE' 'PONTEVEDRA'
#  'AVILA' 'BURGOS' 'MADRID' 'PALENCIA' 'SALAMANCA' 'SEGOVIA' 'SORIA'
#  'VALLADOLID' 'ZAMORA' 'CACERES' 'CUENCA' 'GUADALAJARA' 'TOLEDO' 'BADAJOZ'
#  'CIUDAD REAL' 'CORDOBA' 'HUELVA' 'CADIZ' 'CEUTA' 'GRANADA' 'JAEN'
#  'SEVILLA' 'ALMERIA' 'MALAGA' 'MELILLA' 'ALBACETE' 'ALICANTE' 'MURCIA'
#  'CASTELLON' 'TERUEL' 'VALENCIA' 'ARABA/ALAVA' 'HUESCA' 'LA RIOJA'
#  'LLEIDA' 'ZARAGOZA' 'ILLES BALEARS' 'LAS PALMAS' 'STA. CRUZ DE TENERIFE']
#                   Estacion  latitud_of  longitud_of indicativo
# 0  SAN PABLO DE LOS MONTES   39.546944    -4.350556      3298X
# 1     TALAVERA DE LA REINA   39.958611    -4.863611      3365A
# 2        TOLEDO, LORENZANA   39.859444    -4.025556       3259
# 3                   TOLEDO   39.884722    -4.045278      3260B
# 4               MADRIDEJOS   39.491944    -3.528333       4067
# 5    QUINTANAR DE LA ORDEN   39.597500    -3.046944      4061X
#  El codigo en cuestion  200
#
#  La url que vamos a gestionar es:  https://opendata.aemet.es/opendata/sh/9d524e38
#
#         fecha               Estacion Provincia  Temperatura_media  \
# 0  2012-01-26  QUINTANAR DE LA ORDEN    TOLEDO              999.0
# 1  2012-01-27  QUINTANAR DE LA ORDEN    TOLEDO              999.0
# 2  2012-01-28  QUINTANAR DE LA ORDEN    TOLEDO              999.0
# 3  2012-01-29  QUINTANAR DE LA ORDEN    TOLEDO              999.0
# 4  2012-01-30  QUINTANAR DE LA ORDEN    TOLEDO              999.0
#
#    Precipitacion_l_m3  Temperatura_minima  Temperatura_maxima  \
# 0                 0.0               999.0               999.0
# 1                 0.2               999.0               999.0
# 2                 0.0               999.0               999.0
# 3                 0.0               999.0               999.0
# 4                 0.0               999.0               999.0
#
#    Direccion_viento  Velocidad_media  Presion_maxima  Presion_minima  \
# 0             999.0            999.0           999.0           999.0
# 1             999.0            999.0           999.0           999.0
# 2             999.0            999.0           999.0           999.0
# 3             999.0            999.0           999.0           999.0
# 4             999.0            999.0           999.0           999.0
#
#    Prom_temperatura_media_prov  Grados_debajo_siete  Presion_externa
# 0                          0.0                  0.0            999.0
# 1                          0.0                  0.0            999.0
# 2                          0.0                  0.0            999.0
# 3                          0.0                  0.0            999.0
# 4                          0.0                  0.0            999.0
#
#  #########################
#
# Subiendo los datos del año;  2013
# Busqueda por coordenadas
# address_components
# address_components es una lista
# formatted_address
# formatted_address es una lista
# geometry
# geometry es una lista
# place_id
# place_id es una lista
# plus_code
# plus_code es una lista
# types
# types es una lista
# la provincia es:  Castile-La Mancha
# Tenemos info geolocalizada :)
#  39.55678330000001 ,  -3.1920417
#  ... it is possible to extract the province information ...
#  ... province obtained ...
#  the province is: Toledo
# Provincia optenida :)
#  TOLEDO
# ['BARCELONA' 'GIRONA' 'TARRAGONA' 'A CORUÑA' 'ASTURIAS' 'BIZKAIA'
#  'CANTABRIA' 'GIPUZKOA' 'LEON' 'LUGO' 'NAVARRA' 'OURENSE' 'PONTEVEDRA'
#  'AVILA' 'BURGOS' 'MADRID' 'PALENCIA' 'SALAMANCA' 'SEGOVIA' 'SORIA'
#  'VALLADOLID' 'ZAMORA' 'CACERES' 'CUENCA' 'GUADALAJARA' 'TOLEDO' 'BADAJOZ'
#  'CIUDAD REAL' 'CORDOBA' 'HUELVA' 'CADIZ' 'CEUTA' 'GRANADA' 'JAEN'
#  'SEVILLA' 'ALMERIA' 'MALAGA' 'MELILLA' 'ALBACETE' 'ALICANTE' 'MURCIA'
#  'CASTELLON' 'TERUEL' 'VALENCIA' 'ARABA/ALAVA' 'HUESCA' 'LA RIOJA'
#  'LLEIDA' 'ZARAGOZA' 'ILLES BALEARS' 'LAS PALMAS' 'STA. CRUZ DE TENERIFE']
#                   Estacion  latitud_of  longitud_of indicativo
# 0  SAN PABLO DE LOS MONTES   39.546944    -4.350556      3298X
# 1     TALAVERA DE LA REINA   39.958611    -4.863611      3365A
# 2        TOLEDO, LORENZANA   39.859444    -4.025556       3259
# 3                   TOLEDO   39.884722    -4.045278      3260B
# 4               MADRIDEJOS   39.491944    -3.528333       4067
# 5    QUINTANAR DE LA ORDEN   39.597500    -3.046944      4061X
#  El codigo en cuestion  200
#
#  La url que vamos a gestionar es:  https://opendata.aemet.es/opendata/sh/32054b17
#
#         fecha               Estacion Provincia  Temperatura_media  \
# 0  2013-01-25  QUINTANAR DE LA ORDEN    TOLEDO                5.2
# 1  2013-01-26  QUINTANAR DE LA ORDEN    TOLEDO               10.1
# 2  2013-01-27  QUINTANAR DE LA ORDEN    TOLEDO                8.2
# 3  2013-01-28  QUINTANAR DE LA ORDEN    TOLEDO                5.9
# 4  2013-01-29  QUINTANAR DE LA ORDEN    TOLEDO                6.0
#
#    Precipitacion_l_m3  Temperatura_minima  Temperatura_maxima  \
# 0                 0.0                 0.9                 9.6
# 1                 0.1                 5.1                15.1
# 2                 5.7                 4.5                11.8
# 3                 0.0                 1.1                10.7
# 4                 0.0                -1.1                13.0
#
#    Direccion_viento  Velocidad_media  Presion_maxima  Presion_minima  \
# 0              25.0              1.4           937.0           934.5
# 1              32.0              2.2           941.2           935.3
# 2              24.0              3.3           941.5           936.1
# 3              32.0              0.6           948.3           940.1
# 4              18.0              0.3           949.0           947.1
#
#    Prom_temperatura_media_prov  Grados_debajo_siete  Presion_externa
# 0                          5.2                  1.8           935.75
# 1                         10.1                  0.0           938.25
# 2                          8.2                  0.0           938.80
# 3                          5.9                  1.1           944.20
# 4                          6.0                  1.0           948.05
#
#  #########################
#
# Subiendo los datos del año;  2014
# Busqueda por coordenadas
# address_components
# address_components es una lista
# formatted_address
# formatted_address es una lista
# geometry
# geometry es una lista
# place_id
# place_id es una lista
# plus_code
# plus_code es una lista
# types
# types es una lista
# la provincia es:  Castile-La Mancha
# Tenemos info geolocalizada :)
#  39.55678330000001 ,  -3.1920417
#  ... it is possible to extract the province information ...
#  ... province obtained ...
#  the province is: Toledo
# Provincia optenida :)
#  TOLEDO
# ['BARCELONA' 'GIRONA' 'TARRAGONA' 'A CORUÑA' 'ASTURIAS' 'BIZKAIA'
#  'CANTABRIA' 'GIPUZKOA' 'LEON' 'LUGO' 'NAVARRA' 'OURENSE' 'PONTEVEDRA'
#  'AVILA' 'BURGOS' 'MADRID' 'PALENCIA' 'SALAMANCA' 'SEGOVIA' 'SORIA'
#  'VALLADOLID' 'ZAMORA' 'CACERES' 'CUENCA' 'GUADALAJARA' 'TOLEDO' 'BADAJOZ'
#  'CIUDAD REAL' 'CORDOBA' 'HUELVA' 'CADIZ' 'CEUTA' 'GRANADA' 'JAEN'
#  'SEVILLA' 'ALMERIA' 'MALAGA' 'MELILLA' 'ALBACETE' 'ALICANTE' 'MURCIA'
#  'CASTELLON' 'TERUEL' 'VALENCIA' 'ARABA/ALAVA' 'HUESCA' 'LA RIOJA'
#  'LLEIDA' 'ZARAGOZA' 'ILLES BALEARS' 'LAS PALMAS' 'STA. CRUZ DE TENERIFE']
#                   Estacion  latitud_of  longitud_of indicativo
# 0  SAN PABLO DE LOS MONTES   39.546944    -4.350556      3298X
# 1     TALAVERA DE LA REINA   39.958611    -4.863611      3365A
# 2        TOLEDO, LORENZANA   39.859444    -4.025556       3259
# 3                   TOLEDO   39.884722    -4.045278      3260B
# 4               MADRIDEJOS   39.491944    -3.528333       4067
# 5    QUINTANAR DE LA ORDEN   39.597500    -3.046944      4061X
#  El codigo en cuestion  200
#
#  La url que vamos a gestionar es:  https://opendata.aemet.es/opendata/sh/5f7a5717
#
#         fecha               Estacion Provincia  Temperatura_media  \
# 0  2014-01-01  QUINTANAR DE LA ORDEN    TOLEDO                7.8
# 1  2014-01-02  QUINTANAR DE LA ORDEN    TOLEDO                9.5
# 2  2014-01-03  QUINTANAR DE LA ORDEN    TOLEDO               12.0
# 3  2014-01-04  QUINTANAR DE LA ORDEN    TOLEDO                7.4
# 4  2014-01-05  QUINTANAR DE LA ORDEN    TOLEDO                5.0
#
#    Precipitacion_l_m3  Temperatura_minima  Temperatura_maxima  \
# 0                 0.1                 5.4                10.2
# 1                 3.1                 7.5                11.5
# 2                 0.2                 9.4                14.7
# 3                 6.2                 2.7                12.0
# 4                 0.1                 2.6                 7.4
#
#    Direccion_viento  Velocidad_media  Presion_maxima  Presion_minima  \
# 0              25.0              3.1           940.7           935.8
# 1              26.0              6.4           937.5           934.7
# 2              25.0              1.4           940.4           937.1
# 3              24.0              4.2           942.0           930.4
# 4              27.0              1.7           943.8           940.6
#
#    Prom_temperatura_media_prov  Grados_debajo_siete  Presion_externa
# 0                          7.8                  0.0           938.25
# 1                          9.5                  0.0           936.10
# 2                         12.0                  0.0           938.75
# 3                          7.4                  0.0           936.20
# 4                          5.0                  2.0           942.20
#
#  #########################
#
# Subiendo los datos del año;  2015
# Busqueda por coordenadas
# address_components
# address_components es una lista
# formatted_address
# formatted_address es una lista
# geometry
# geometry es una lista
# place_id
# place_id es una lista
# plus_code
# plus_code es una lista
# types
# types es una lista
# la provincia es:  Castile-La Mancha
# Tenemos info geolocalizada :)
#  39.55678330000001 ,  -3.1920417
#  ... it is possible to extract the province information ...
#  ... province obtained ...
#  the province is: Toledo
# Provincia optenida :)
#  TOLEDO
# ['BARCELONA' 'GIRONA' 'TARRAGONA' 'A CORUÑA' 'ASTURIAS' 'BIZKAIA'
#  'CANTABRIA' 'GIPUZKOA' 'LEON' 'LUGO' 'NAVARRA' 'OURENSE' 'PONTEVEDRA'
#  'AVILA' 'BURGOS' 'MADRID' 'PALENCIA' 'SALAMANCA' 'SEGOVIA' 'SORIA'
#  'VALLADOLID' 'ZAMORA' 'CACERES' 'CUENCA' 'GUADALAJARA' 'TOLEDO' 'BADAJOZ'
#  'CIUDAD REAL' 'CORDOBA' 'HUELVA' 'CADIZ' 'CEUTA' 'GRANADA' 'JAEN'
#  'SEVILLA' 'ALMERIA' 'MALAGA' 'MELILLA' 'ALBACETE' 'ALICANTE' 'MURCIA'
#  'CASTELLON' 'TERUEL' 'VALENCIA' 'ARABA/ALAVA' 'HUESCA' 'LA RIOJA'
#  'LLEIDA' 'ZARAGOZA' 'ILLES BALEARS' 'LAS PALMAS' 'STA. CRUZ DE TENERIFE']
#                   Estacion  latitud_of  longitud_of indicativo
# 0  SAN PABLO DE LOS MONTES   39.546944    -4.350556      3298X
# 1     TALAVERA DE LA REINA   39.958611    -4.863611      3365A
# 2        TOLEDO, LORENZANA   39.859444    -4.025556       3259
# 3                   TOLEDO   39.884722    -4.045278      3260B
# 4               MADRIDEJOS   39.491944    -3.528333       4067
# 5    QUINTANAR DE LA ORDEN   39.597500    -3.046944      4061X
#  El codigo en cuestion  200
#
#  La url que vamos a gestionar es:  https://opendata.aemet.es/opendata/sh/f3e361a2
#
#         fecha               Estacion Provincia  Temperatura_media  \
# 0  2015-01-01  QUINTANAR DE LA ORDEN    TOLEDO                4.3
# 1  2015-01-02  QUINTANAR DE LA ORDEN    TOLEDO                4.5
# 2  2015-01-03  QUINTANAR DE LA ORDEN    TOLEDO              999.0
# 3  2015-01-04  QUINTANAR DE LA ORDEN    TOLEDO                6.6
# 4  2015-01-05  QUINTANAR DE LA ORDEN    TOLEDO                7.2
#
#    Precipitacion_l_m3  Temperatura_minima  Temperatura_maxima  \
# 0                 0.0                -3.2                11.8
# 1                 0.0                -3.6                12.6
# 2               999.0               999.0               999.0
# 3                 0.0                -1.8                15.1
# 4                 0.0                -0.7                15.1
#
#    Direccion_viento  Velocidad_media  Presion_maxima  Presion_minima  \
# 0              16.0              0.6           955.4           949.6
# 1               4.0              0.6           957.4           954.2
# 2             999.0              0.3           999.0           999.0
# 3              31.0              0.6           954.7           949.5
# 4              18.0              0.8           949.6           945.7
#
#    Prom_temperatura_media_prov  Grados_debajo_siete  Presion_externa
# 0                          4.3                  2.7           952.50
# 1                          4.5                  2.5           955.80
# 2                          0.0                  0.0           999.00
# 3                          6.6                  0.4           952.10
# 4                          7.2                  0.0           947.65
#
#  #########################
#
# Subiendo los datos del año;  2016
# Busqueda por coordenadas
# address_components
# address_components es una lista
# formatted_address
# formatted_address es una lista
# geometry
# geometry es una lista
# place_id
# place_id es una lista
# plus_code
# plus_code es una lista
# types
# types es una lista
# la provincia es:  Castile-La Mancha
# Tenemos info geolocalizada :)
#  39.55678330000001 ,  -3.1920417
#  ... it is possible to extract the province information ...
#  ... province obtained ...
#  the province is: Toledo
# Provincia optenida :)
#  TOLEDO
# ['BARCELONA' 'GIRONA' 'TARRAGONA' 'A CORUÑA' 'ASTURIAS' 'BIZKAIA'
#  'CANTABRIA' 'GIPUZKOA' 'LEON' 'LUGO' 'NAVARRA' 'OURENSE' 'PONTEVEDRA'
#  'AVILA' 'BURGOS' 'MADRID' 'PALENCIA' 'SALAMANCA' 'SEGOVIA' 'SORIA'
#  'VALLADOLID' 'ZAMORA' 'CACERES' 'CUENCA' 'GUADALAJARA' 'TOLEDO' 'BADAJOZ'
#  'CIUDAD REAL' 'CORDOBA' 'HUELVA' 'CADIZ' 'CEUTA' 'GRANADA' 'JAEN'
#  'SEVILLA' 'ALMERIA' 'MALAGA' 'MELILLA' 'ALBACETE' 'ALICANTE' 'MURCIA'
#  'CASTELLON' 'TERUEL' 'VALENCIA' 'ARABA/ALAVA' 'HUESCA' 'LA RIOJA'
#  'LLEIDA' 'ZARAGOZA' 'ILLES BALEARS' 'LAS PALMAS' 'STA. CRUZ DE TENERIFE']
#                   Estacion  latitud_of  longitud_of indicativo
# 0  SAN PABLO DE LOS MONTES   39.546944    -4.350556      3298X
# 1     TALAVERA DE LA REINA   39.958611    -4.863611      3365A
# 2        TOLEDO, LORENZANA   39.859444    -4.025556       3259
# 3                   TOLEDO   39.884722    -4.045278      3260B
# 4               MADRIDEJOS   39.491944    -3.528333       4067
# 5    QUINTANAR DE LA ORDEN   39.597500    -3.046944      4061X
#  El codigo en cuestion  200
#
#  La url que vamos a gestionar es:  https://opendata.aemet.es/opendata/sh/a7a7bfb4
#
#         fecha               Estacion Provincia  Temperatura_media  \
# 0  2016-01-01  QUINTANAR DE LA ORDEN    TOLEDO               12.5
# 1  2016-01-02  QUINTANAR DE LA ORDEN    TOLEDO                8.4
# 2  2016-01-03  QUINTANAR DE LA ORDEN    TOLEDO                8.2
# 3  2016-01-04  QUINTANAR DE LA ORDEN    TOLEDO               11.2
# 4  2016-01-05  QUINTANAR DE LA ORDEN    TOLEDO                5.3
#
#    Precipitacion_l_m3  Temperatura_minima  Temperatura_maxima  \
# 0                 7.6                 9.8                15.2
# 1                 0.0                 4.7                12.0
# 2                 0.0                 3.9                12.4
# 3                 7.6                 8.2                14.3
# 4                 2.5                 2.1                 8.5
#
#    Direccion_viento  Velocidad_media  Presion_maxima  Presion_minima  \
# 0              23.0              2.2           943.9           937.6
# 1              32.0              1.4           942.9           938.5
# 2              26.0              5.0           941.7           931.2
# 3              26.0              6.1           931.2           923.9
# 4              31.0              3.9           933.8           925.6
#
#    Prom_temperatura_media_prov  Grados_debajo_siete  Presion_externa
# 0                         12.5                  0.0           940.75
# 1                          8.4                  0.0           940.70
# 2                          8.2                  0.0           936.45
# 3                         11.2                  0.0           927.55
# 4                          5.3                  1.7           929.70
#
#  #########################
#
# Subiendo los datos del año;  2017
# Busqueda por coordenadas
# address_components
# address_components es una lista
# formatted_address
# formatted_address es una lista
# geometry
# geometry es una lista
# place_id
# place_id es una lista
# plus_code
# plus_code es una lista
# types
# types es una lista
# la provincia es:  Castile-La Mancha
# Tenemos info geolocalizada :)
#  39.55678330000001 ,  -3.1920417
#  ... it is possible to extract the province information ...
#  ... province obtained ...
#  the province is: Toledo
# Provincia optenida :)
#  TOLEDO
# ['BARCELONA' 'GIRONA' 'TARRAGONA' 'A CORUÑA' 'ASTURIAS' 'BIZKAIA'
#  'CANTABRIA' 'GIPUZKOA' 'LEON' 'LUGO' 'NAVARRA' 'OURENSE' 'PONTEVEDRA'
#  'AVILA' 'BURGOS' 'MADRID' 'PALENCIA' 'SALAMANCA' 'SEGOVIA' 'SORIA'
#  'VALLADOLID' 'ZAMORA' 'CACERES' 'CUENCA' 'GUADALAJARA' 'TOLEDO' 'BADAJOZ'
#  'CIUDAD REAL' 'CORDOBA' 'HUELVA' 'CADIZ' 'CEUTA' 'GRANADA' 'JAEN'
#  'SEVILLA' 'ALMERIA' 'MALAGA' 'MELILLA' 'ALBACETE' 'ALICANTE' 'MURCIA'
#  'CASTELLON' 'TERUEL' 'VALENCIA' 'ARABA/ALAVA' 'HUESCA' 'LA RIOJA'
#  'LLEIDA' 'ZARAGOZA' 'ILLES BALEARS' 'LAS PALMAS' 'STA. CRUZ DE TENERIFE']
#                   Estacion  latitud_of  longitud_of indicativo
# 0  SAN PABLO DE LOS MONTES   39.546944    -4.350556      3298X
# 1     TALAVERA DE LA REINA   39.958611    -4.863611      3365A
# 2        TOLEDO, LORENZANA   39.859444    -4.025556       3259
# 3                   TOLEDO   39.884722    -4.045278      3260B
# 4               MADRIDEJOS   39.491944    -3.528333       4067
# 5    QUINTANAR DE LA ORDEN   39.597500    -3.046944      4061X
#  El codigo en cuestion  200
#
#  La url que vamos a gestionar es:  https://opendata.aemet.es/opendata/sh/306f3cf7
#
#         fecha               Estacion Provincia  Temperatura_media  \
# 0  2017-01-01  QUINTANAR DE LA ORDEN    TOLEDO               -0.8
# 1  2017-01-02  QUINTANAR DE LA ORDEN    TOLEDO                4.8
# 2  2017-01-03  QUINTANAR DE LA ORDEN    TOLEDO                7.4
# 3  2017-01-04  QUINTANAR DE LA ORDEN    TOLEDO                6.0
# 4  2017-01-05  QUINTANAR DE LA ORDEN    TOLEDO                7.2
#
#    Precipitacion_l_m3  Temperatura_minima  Temperatura_maxima  \
# 0                 0.0                -1.9                 0.4
# 1                 0.1                -1.5                11.1
# 2                 0.0                 1.4                13.3
# 3                 0.0                 1.0                11.1
# 4                 0.0                 2.1                12.4
#
#    Direccion_viento  Velocidad_media  Presion_maxima  Presion_minima  \
# 0              21.0              1.1           947.3           940.8
# 1              18.0              0.6           942.3           939.0
# 2              26.0              1.1           945.6           941.6
# 3              32.0              1.4           946.9           943.5
# 4              99.0              2.2           944.7           941.6
#
#    Prom_temperatura_media_prov  Grados_debajo_siete  Presion_externa
# 0                         -0.8                  7.8           944.05
# 1                          4.8                  2.2           940.65
# 2                          7.4                  0.0           943.60
# 3                          6.0                  1.0           945.20
# 4                          7.2                  0.0           943.15
#
#  #########################
#
# Subiendo los datos del año;  2018
# Busqueda por coordenadas
# address_components
# address_components es una lista
# formatted_address
# formatted_address es una lista
# geometry
# geometry es una lista
# place_id
# place_id es una lista
# plus_code
# plus_code es una lista
# types
# types es una lista
# la provincia es:  Castile-La Mancha
# Tenemos info geolocalizada :)
#  39.55678330000001 ,  -3.1920417
#  ... it is possible to extract the province information ...
#  ... province obtained ...
#  the province is: Toledo
# Provincia optenida :)
#  TOLEDO
# ['BARCELONA' 'GIRONA' 'TARRAGONA' 'A CORUÑA' 'ASTURIAS' 'BIZKAIA'
#  'CANTABRIA' 'GIPUZKOA' 'LEON' 'LUGO' 'NAVARRA' 'OURENSE' 'PONTEVEDRA'
#  'AVILA' 'BURGOS' 'MADRID' 'PALENCIA' 'SALAMANCA' 'SEGOVIA' 'SORIA'
#  'VALLADOLID' 'ZAMORA' 'CACERES' 'CUENCA' 'GUADALAJARA' 'TOLEDO' 'BADAJOZ'
#  'CIUDAD REAL' 'CORDOBA' 'HUELVA' 'CADIZ' 'CEUTA' 'GRANADA' 'JAEN'
#  'SEVILLA' 'ALMERIA' 'MALAGA' 'MELILLA' 'ALBACETE' 'ALICANTE' 'MURCIA'
#  'CASTELLON' 'TERUEL' 'VALENCIA' 'ARABA/ALAVA' 'HUESCA' 'LA RIOJA'
#  'LLEIDA' 'ZARAGOZA' 'ILLES BALEARS' 'LAS PALMAS' 'STA. CRUZ DE TENERIFE']
#                   Estacion  latitud_of  longitud_of indicativo
# 0  SAN PABLO DE LOS MONTES   39.546944    -4.350556      3298X
# 1     TALAVERA DE LA REINA   39.958611    -4.863611      3365A
# 2        TOLEDO, LORENZANA   39.859444    -4.025556       3259
# 3                   TOLEDO   39.884722    -4.045278      3260B
# 4               MADRIDEJOS   39.491944    -3.528333       4067
# 5    QUINTANAR DE LA ORDEN   39.597500    -3.046944      4061X
#  El codigo en cuestion  200
#
#  La url que vamos a gestionar es:  https://opendata.aemet.es/opendata/sh/1f18f87e
#
#         fecha               Estacion Provincia  Temperatura_media  \
# 0  2018-01-01  QUINTANAR DE LA ORDEN    TOLEDO                5.6
# 1  2018-01-02  QUINTANAR DE LA ORDEN    TOLEDO                7.6
# 2  2018-01-03  QUINTANAR DE LA ORDEN    TOLEDO                9.1
# 3  2018-01-04  QUINTANAR DE LA ORDEN    TOLEDO               10.2
# 4  2018-01-05  QUINTANAR DE LA ORDEN    TOLEDO               10.0
#
#    Precipitacion_l_m3  Temperatura_minima  Temperatura_maxima  \
# 0                 0.0                 0.0                11.1
# 1                 0.0                 2.7                12.5
# 2                 0.1                 4.7                13.5
# 3                 0.0                 6.6                13.8
# 4                 7.3                 8.4                11.5
#
#    Direccion_viento  Velocidad_media  Presion_maxima  Presion_minima  \
# 0              32.0              1.4           952.5           948.8
# 1              28.0              1.1           952.2           949.5
# 2              25.0              1.1           952.7           949.3
# 3              25.0              0.8           949.9           941.5
# 4              25.0              5.0           941.5           923.9
#
#    Prom_temperatura_media_prov  Grados_debajo_siete  Presion_externa
# 0                          5.6                  1.4           950.65
# 1                          7.6                  0.0           950.85
# 2                          9.1                  0.0           951.00
# 3                         10.2                  0.0           945.70
# 4                         10.0                  0.0           932.70
#
#  #########################
#
# Subiendo los datos del año;  2019
# Busqueda por coordenadas
# address_components
# address_components es una lista
# formatted_address
# formatted_address es una lista
# geometry
# geometry es una lista
# place_id
# place_id es una lista
# plus_code
# plus_code es una lista
# types
# types es una lista
# la provincia es:  Castile-La Mancha
# Tenemos info geolocalizada :)
#  39.55678330000001 ,  -3.1920417
#  ... it is possible to extract the province information ...
#  ... province obtained ...
#  the province is: Toledo
# Provincia optenida :)
#  TOLEDO
# ['BARCELONA' 'GIRONA' 'TARRAGONA' 'A CORUÑA' 'ASTURIAS' 'BIZKAIA'
#  'CANTABRIA' 'GIPUZKOA' 'LEON' 'LUGO' 'NAVARRA' 'OURENSE' 'PONTEVEDRA'
#  'AVILA' 'BURGOS' 'MADRID' 'PALENCIA' 'SALAMANCA' 'SEGOVIA' 'SORIA'
#  'VALLADOLID' 'ZAMORA' 'CACERES' 'CUENCA' 'GUADALAJARA' 'TOLEDO' 'BADAJOZ'
#  'CIUDAD REAL' 'CORDOBA' 'HUELVA' 'CADIZ' 'CEUTA' 'GRANADA' 'JAEN'
#  'SEVILLA' 'ALMERIA' 'MALAGA' 'MELILLA' 'ALBACETE' 'ALICANTE' 'MURCIA'
#  'CASTELLON' 'TERUEL' 'VALENCIA' 'ARABA/ALAVA' 'HUESCA' 'LA RIOJA'
#  'LLEIDA' 'ZARAGOZA' 'ILLES BALEARS' 'LAS PALMAS' 'STA. CRUZ DE TENERIFE']
#                   Estacion  latitud_of  longitud_of indicativo
# 0  SAN PABLO DE LOS MONTES   39.546944    -4.350556      3298X
# 1     TALAVERA DE LA REINA   39.958611    -4.863611      3365A
# 2        TOLEDO, LORENZANA   39.859444    -4.025556       3259
# 3                   TOLEDO   39.884722    -4.045278      3260B
# 4               MADRIDEJOS   39.491944    -3.528333       4067
# 5    QUINTANAR DE LA ORDEN   39.597500    -3.046944      4061X
#  El codigo en cuestion  200
#
#  La url que vamos a gestionar es:  https://opendata.aemet.es/opendata/sh/95d8154e
#
#         fecha               Estacion Provincia  Temperatura_media  \
# 0  2019-01-24  QUINTANAR DE LA ORDEN    TOLEDO               10.0
# 1  2019-01-25  QUINTANAR DE LA ORDEN    TOLEDO                9.6
# 2  2019-01-26  QUINTANAR DE LA ORDEN    TOLEDO                7.4
# 3  2019-01-27  QUINTANAR DE LA ORDEN    TOLEDO                6.2
# 4  2019-01-28  QUINTANAR DE LA ORDEN    TOLEDO                6.0
#
#    Precipitacion_l_m3  Temperatura_minima  Temperatura_maxima  \
# 0                 0.0                 5.2                14.8
# 1                 0.0                 3.7                15.5
# 2                 0.1                -0.4                15.1
# 3                 0.0                 0.4                12.1
# 4                 0.0                -1.1                13.1
#
#    Direccion_viento  Velocidad_media  Presion_maxima  Presion_minima  \
# 0               4.0              1.9           999.0           999.0
# 1               2.0              1.9           999.0           999.0
# 2               4.0              0.8           999.0           999.0
# 3               3.0              2.5           999.0           999.0
# 4              32.0              2.5           999.0           999.0
#
#    Prom_temperatura_media_prov  Grados_debajo_siete  Presion_externa
# 0                         10.0                  0.0            999.0
# 1                          9.6                  0.0            999.0
# 2                          7.4                  0.0            999.0
# 3                          6.2                  0.8            999.0
# 4                          6.0                  1.0            999.0
#
#  #########################
#
# Subiendo los datos del año;  2020
# Busqueda por coordenadas
# address_components
# address_components es una lista
# formatted_address
# formatted_address es una lista
# geometry
# geometry es una lista
# place_id
# place_id es una lista
# plus_code
# plus_code es una lista
# types
# types es una lista
# la provincia es:  Castile-La Mancha
# Tenemos info geolocalizada :)
#  39.55678330000001 ,  -3.1920417
#  ... it is possible to extract the province information ...
#  ... province obtained ...
#  the province is: Toledo
# Provincia optenida :)
#  TOLEDO
# ['BARCELONA' 'GIRONA' 'TARRAGONA' 'A CORUÑA' 'ASTURIAS' 'BIZKAIA'
#  'CANTABRIA' 'GIPUZKOA' 'LEON' 'LUGO' 'NAVARRA' 'OURENSE' 'PONTEVEDRA'
#  'AVILA' 'BURGOS' 'MADRID' 'PALENCIA' 'SALAMANCA' 'SEGOVIA' 'SORIA'
#  'VALLADOLID' 'ZAMORA' 'CACERES' 'CUENCA' 'GUADALAJARA' 'TOLEDO' 'BADAJOZ'
#  'CIUDAD REAL' 'CORDOBA' 'HUELVA' 'CADIZ' 'CEUTA' 'GRANADA' 'JAEN'
#  'SEVILLA' 'ALMERIA' 'MALAGA' 'MELILLA' 'ALBACETE' 'ALICANTE' 'MURCIA'
#  'CASTELLON' 'TERUEL' 'VALENCIA' 'ARABA/ALAVA' 'HUESCA' 'LA RIOJA'
#  'LLEIDA' 'ZARAGOZA' 'ILLES BALEARS' 'LAS PALMAS' 'STA. CRUZ DE TENERIFE']
#                   Estacion  latitud_of  longitud_of indicativo
# 0  SAN PABLO DE LOS MONTES   39.546944    -4.350556      3298X
# 1     TALAVERA DE LA REINA   39.958611    -4.863611      3365A
# 2        TOLEDO, LORENZANA   39.859444    -4.025556       3259
# 3                   TOLEDO   39.884722    -4.045278      3260B
# 4               MADRIDEJOS   39.491944    -3.528333       4067
# 5    QUINTANAR DE LA ORDEN   39.597500    -3.046944      4061X
#  El codigo en cuestion  200
#
#  La url que vamos a gestionar es:  https://opendata.aemet.es/opendata/sh/fbf10079
#
#         fecha               Estacion Provincia  Temperatura_media  \
# 0  2020-01-01  QUINTANAR DE LA ORDEN    TOLEDO                2.7
# 1  2020-01-02  QUINTANAR DE LA ORDEN    TOLEDO                5.7
# 2  2020-01-03  QUINTANAR DE LA ORDEN    TOLEDO                3.5
# 3  2020-01-04  QUINTANAR DE LA ORDEN    TOLEDO                4.9
# 4  2020-01-05  QUINTANAR DE LA ORDEN    TOLEDO                6.0
#
#    Precipitacion_l_m3  Temperatura_minima  Temperatura_maxima  \
# 0                 0.0                -0.6                 6.0
# 1                 0.8                -1.7                13.1
# 2                 0.1                -0.2                 7.2
# 3                 0.0                -1.7                11.5
# 4                 0.0                -1.6                13.6
#
#    Direccion_viento  Velocidad_media  Presion_maxima  Presion_minima  \
# 0              24.0              0.0           951.5           948.6
# 1              99.0              0.0           950.4           947.7
# 2               2.0              0.8           951.9           949.0
# 3               3.0              0.6           952.0           948.6
# 4               4.0              0.3           949.8           945.5
#
#    Prom_temperatura_media_prov  Grados_debajo_siete  Presion_externa
# 0                          2.7                  4.3           950.05
# 1                          5.7                  1.3           949.05
# 2                          3.5                  3.5           950.45
# 3                          4.9                  2.1           950.30
# 4                          6.0                  1.0           947.65
#
#  #########################
#
# Subiendo los datos del año;  2021
# Busqueda por coordenadas
# address_components
# address_components es una lista
# formatted_address
# formatted_address es una lista
# geometry
# geometry es una lista
# place_id
# place_id es una lista
# plus_code
# plus_code es una lista
# types
# types es una lista
# la provincia es:  Castile-La Mancha
# Tenemos info geolocalizada :)
#  39.55678330000001 ,  -3.1920417
#  ... it is possible to extract the province information ...
#  ... province obtained ...
#  the province is: Toledo
# Provincia optenida :)
#  TOLEDO
# ['BARCELONA' 'GIRONA' 'TARRAGONA' 'A CORUÑA' 'ASTURIAS' 'BIZKAIA'
#  'CANTABRIA' 'GIPUZKOA' 'LEON' 'LUGO' 'NAVARRA' 'OURENSE' 'PONTEVEDRA'
#  'AVILA' 'BURGOS' 'MADRID' 'PALENCIA' 'SALAMANCA' 'SEGOVIA' 'SORIA'
#  'VALLADOLID' 'ZAMORA' 'CACERES' 'CUENCA' 'GUADALAJARA' 'TOLEDO' 'BADAJOZ'
#  'CIUDAD REAL' 'CORDOBA' 'HUELVA' 'CADIZ' 'CEUTA' 'GRANADA' 'JAEN'
#  'SEVILLA' 'ALMERIA' 'MALAGA' 'MELILLA' 'ALBACETE' 'ALICANTE' 'MURCIA'
#  'CASTELLON' 'TERUEL' 'VALENCIA' 'ARABA/ALAVA' 'HUESCA' 'LA RIOJA'
#  'LLEIDA' 'ZARAGOZA' 'ILLES BALEARS' 'LAS PALMAS' 'STA. CRUZ DE TENERIFE']
#                   Estacion  latitud_of  longitud_of indicativo
# 0  SAN PABLO DE LOS MONTES   39.546944    -4.350556      3298X
# 1     TALAVERA DE LA REINA   39.958611    -4.863611      3365A
# 2        TOLEDO, LORENZANA   39.859444    -4.025556       3259
# 3                   TOLEDO   39.884722    -4.045278      3260B
# 4               MADRIDEJOS   39.491944    -3.528333       4067
# 5    QUINTANAR DE LA ORDEN   39.597500    -3.046944      4061X
#  El codigo en cuestion  200
#
#  La url que vamos a gestionar es:  https://opendata.aemet.es/opendata/sh/f75912da
#
#         fecha               Estacion Provincia  Temperatura_media  \
# 0  2021-01-01  QUINTANAR DE LA ORDEN    TOLEDO              999.0
# 1  2021-01-05  QUINTANAR DE LA ORDEN    TOLEDO                0.2
# 2  2021-01-06  QUINTANAR DE LA ORDEN    TOLEDO                1.2
# 3  2021-01-07  QUINTANAR DE LA ORDEN    TOLEDO                1.6
# 4  2021-01-08  QUINTANAR DE LA ORDEN    TOLEDO                2.0
#
#    Precipitacion_l_m3  Temperatura_minima  Temperatura_maxima  \
# 0                 0.3               999.0               999.0
# 1                 0.0                -4.8                 5.1
# 2                 1.1                -5.4                 7.9
# 3                 8.4                 1.0                 2.2
# 4                18.6                 1.3                 2.8
#
#    Direccion_viento  Velocidad_media  Presion_maxima  Presion_minima  \
# 0              33.0              3.6           933.1           932.6
# 1               4.0              0.8           931.7           928.3
# 2              15.0              0.8           931.8           928.4
# 3              15.0              1.9           929.8           927.5
# 4              12.0              1.9           928.7           919.9
#
#    Prom_temperatura_media_prov  Grados_debajo_siete  Presion_externa
# 0                          0.0                  0.0           932.85
# 1                          0.2                  6.8           930.00
# 2                          1.2                  5.8           930.10
# 3                          1.6                  5.4           928.65
# 4                          2.0                  5.0           924.30
#
#  #########################
#
# Subiendo los datos del año;  2022
# Busqueda por coordenadas
# address_components
# address_components es una lista
# formatted_address
# formatted_address es una lista
# geometry
# geometry es una lista
# place_id
# place_id es una lista
# plus_code
# plus_code es una lista
# types
# types es una lista
# la provincia es:  Castile-La Mancha
# Tenemos info geolocalizada :)
#  39.55678330000001 ,  -3.1920417
#  ... it is possible to extract the province information ...
#  ... province obtained ...
#  the province is: Toledo
# Provincia optenida :)
#  TOLEDO
# ['BARCELONA' 'GIRONA' 'TARRAGONA' 'A CORUÑA' 'ASTURIAS' 'BIZKAIA'
#  'CANTABRIA' 'GIPUZKOA' 'LEON' 'LUGO' 'NAVARRA' 'OURENSE' 'PONTEVEDRA'
#  'AVILA' 'BURGOS' 'MADRID' 'PALENCIA' 'SALAMANCA' 'SEGOVIA' 'SORIA'
#  'VALLADOLID' 'ZAMORA' 'CACERES' 'CUENCA' 'GUADALAJARA' 'TOLEDO' 'BADAJOZ'
#  'CIUDAD REAL' 'CORDOBA' 'HUELVA' 'CADIZ' 'CEUTA' 'GRANADA' 'JAEN'
#  'SEVILLA' 'ALMERIA' 'MALAGA' 'MELILLA' 'ALBACETE' 'ALICANTE' 'MURCIA'
#  'CASTELLON' 'TERUEL' 'VALENCIA' 'ARABA/ALAVA' 'HUESCA' 'LA RIOJA'
#  'LLEIDA' 'ZARAGOZA' 'ILLES BALEARS' 'LAS PALMAS' 'STA. CRUZ DE TENERIFE']
#                   Estacion  latitud_of  longitud_of indicativo
# 0  SAN PABLO DE LOS MONTES   39.546944    -4.350556      3298X
# 1     TALAVERA DE LA REINA   39.958611    -4.863611      3365A
# 2        TOLEDO, LORENZANA   39.859444    -4.025556       3259
# 3                   TOLEDO   39.884722    -4.045278      3260B
# 4               MADRIDEJOS   39.491944    -3.528333       4067
# 5    QUINTANAR DE LA ORDEN   39.597500    -3.046944      4061X
#  El codigo en cuestion  200
#
#  La url que vamos a gestionar es:  https://opendata.aemet.es/opendata/sh/dea90b41
#
#         fecha               Estacion Provincia  Temperatura_media  \
# 0  2022-01-01  QUINTANAR DE LA ORDEN    TOLEDO               11.2
# 1  2022-01-02  QUINTANAR DE LA ORDEN    TOLEDO                9.3
# 2  2022-01-03  QUINTANAR DE LA ORDEN    TOLEDO               10.1
# 3  2022-01-04  QUINTANAR DE LA ORDEN    TOLEDO               10.3
# 4  2022-01-05  QUINTANAR DE LA ORDEN    TOLEDO                5.6
#
#    Precipitacion_l_m3  Temperatura_minima  Temperatura_maxima  \
# 0                 0.0                 2.5                20.0
# 1                 0.0                 2.2                16.4
# 2                 0.0                 2.8                17.4
# 3                 1.1                 4.5                16.1
# 4                 2.0                 2.0                 9.2
#
#    Direccion_viento  Velocidad_media  Presion_maxima  Presion_minima  \
# 0              99.0              0.6           948.7           946.0
# 1               4.0              0.0           949.4           947.0
# 2              26.0              0.0           947.7           941.0
# 3              24.0              3.3           941.1           930.0
# 4               3.0              1.9           938.7           934.3
#
#    Prom_temperatura_media_prov  Grados_debajo_siete  Presion_externa
# 0                         11.2                  0.0           947.35
# 1                          9.3                  0.0           948.20
# 2                         10.1                  0.0           944.35
# 3                         10.3                  0.0           935.55
# 4                          5.6                  1.4           936.50

# %%
# !pip install pymysql
# Out:
# Requirement already satisfied: pymysql in /home/bluetab/anaconda3/lib/python3.9/site-packages (1.0.2)

# %%
import pymysql
import matplotlib.pyplot as plt
import logging
import requests
import pandas as pd


host = '34.175.164.167' #este el el host nuevo
user = 'admin'
password = '12345678'
database = 'GET_DATABASE'




'''
def conectame(host, user, password, database):

    #conn = pymysql.connect(host=host, user=user, password=password, port=3306, db='GET_DATABASE',charset='utf8')

    connection = pymysql.connect(host=host,
                                user=user,
                                password=password,
                                db=database)

    cursor = connection.cursor()

    return cursor
cursor = conectame(host, user, password, database)
'''

logger = logging.getLogger()
logger.setLevel(logging.INFO)

try:
    conn = pymysql.connect(host=host, user=user, passwd=password, db=database, connect_timeout=5)
except pymysql.MySQLError as e:
    logger.error("ERROR: Unexpected error: Could not connect to MySQL instance.")
    logger.error(e)
    sys.exit()

logger.info("SUCCESS: Connection to RDS MySQL instance succeeded")

def run_query(q):
  with pymysql.connect(host=host,
                             user=user,
                             password=password,
                             db=database) as conn:
                             return pd.read_sql(q, conn)
q = '''
select * from METEREOLOGIA;


'''




datos_mete = run_query(q)

humedad_media_dia =  pd.pivot_table(datos_mete, values='Temperatura_media' , index='fecha')


    
humedad_media_dia['Temperatura_media'].plot()
plt.title('Evolución de la temperatura ')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # App shiny
#
# Si tenemos que utilizar la aplicación de RSTUDIO conectado a la API y demás necesitamos replicar la funcionabilidad on premise en el cloud, para ello vamos a crear las tablas de 'usuarios', 'api_keys' y 'tierras'

# %%
checkTableExists(conn, 'usuarios')
# Out:
# False

# %%
tabla_de_interes = 'usuarios'

try: 
    q = '''CREATE TABLE usuarios (

        user_id  serial, 
        usuario varchar(255), 
        nombre varchar(255),
        apellido varchar(255),
        correo_electronico varchar(255), 
        password varchar(255),
        primary key (user_id)


        );'''

    run_query(q)

except: 
    print('ALgo ocurre con la tabla de usuarios, mira la conexión igual ya se ha creado la tabla')


try: 
    
    q = '''
CREATE TABLE api_keys (

    api_id serial, 
    api_key_name varchar(255),
    api_key_value varchar(400),
    user_id int, 
    primary key (api_id)
    );



'''

    run_query(q)
    
except: 
    
    print('Algo ocurre con la tabla de api_keys, mira la conexión igual ya se ha creado')
    


try: 

    q = '''
    CREATE TABLE tierras (

    tierra_id serial, 
    descripcion varchar(300),
    coordenadas varchar(255),
    user_id varchar(255), 
    foreign key (tierra_id) references usuarios(user_id)


    );



    '''

    run_query(q)

except: 
    
    print('ALgo ocurre con la tabla de tierras, mira la conexión igual ya se ha creado la tabla')
# Out:
# ALgo ocurre con la tabla de usuarios, mira la conexión igual ya se ha creado la tabla
# Algo ocurre con la tabla de api_keys, mira la conexión igual ya se ha creado
# ALgo ocurre con la tabla de tierras, mira la conexión igual ya se ha creado la tabla
